# %%
import copy
import random
import scipy

import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer

from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ## Set parameters

# %%
k = 2
take_x_most_common_words = 1000
num_sampling_iterations = 5
np.random.seed(10) # Set random seed for consistency

# %%
# 5331 pos, 5331 neg reviews; the lines here refer to lines in the pos and neg review files separately
train_lines = list(range(0,199))
train_lines.extend(range(200,1551))
train_lines.extend(range(1600,5331))

test_lines = list(range(1551, 1600))
test_lines.insert(0,199)

# %% [markdown]
# ## Load data
# Review variable names suffixed with `_ss` are a list of strings, with one string representing an entire review.
#
# Review variable names suffixed with `_ls` are a list of list of strings, with one string representing an entire review.
#
# Review variable names suffixed with `_vc` are lists of lists of integers, with a list of integers representing an entire review, and an integer representing a word.
#
# Review variable names suffixed with `_oh` are one-hot encoded pandas Dataframes of reviews, with the column names representing the numeric representation of a word.

# %% [markdown]
# ### Obtain Rotten tomatoes data

# %%
def get_rt_data(fname, line_range):
    with open(fname, encoding='utf-8', errors='ignore') as file:
        all_lines = list(file)
        as_single_string = [all_lines[line_num] for line_num in line_range]
        as_list_of_strings = [line.strip().split() for line in as_single_string]
    return as_single_string, as_list_of_strings

# %%
any_y = np.concatenate((np.ones(len(train_lines),dtype=bool), np.zeros(len(train_lines), dtype=bool)))

train_pos_reviews_ss, train_pos_reviews_ls = get_rt_data("./datasets/rt-polaritydata/rt-polarity-mangled.pos", train_lines) 
train_neg_reviews_ss, train_neg_reviews_ls = get_rt_data("./datasets/rt-polaritydata/rt-polarity-mangled.neg", train_lines)
train_reviews_ss = train_pos_reviews_ss + train_neg_reviews_ss 
train_reviews_ls = train_pos_reviews_ls + train_neg_reviews_ls
train_y = np.concatenate(
    (np.ones(len(train_lines),dtype=bool), 
     np.zeros(len(train_lines), dtype=bool))
)

test_pos_reviews_ss, test_pos_reviews_ls = get_rt_data("./datasets/rt-polaritydata/rt-polarity-mangled.pos", test_lines) 
test_neg_reviews_ss, test_neg_reviews_ls = get_rt_data("./datasets/rt-polaritydata/rt-polarity-mangled.neg", test_lines) 
test_reviews_ss = test_pos_reviews_ss + test_neg_reviews_ss 
test_reviews_ls = test_pos_reviews_ls + test_neg_reviews_ls
test_y = np.concatenate(
    (np.ones(len(test_lines),dtype=bool), 
     np.zeros(len(test_lines), dtype=bool))
)

all_reviews_ss = train_reviews_ss + test_reviews_ss
all_reviews_ls = train_reviews_ls + test_reviews_ls

# %%
print(f"Train set has {len(train_reviews_ss)} reviews; example review:\n{train_reviews_ls[0]}")
# Out:
# Train set has 10562 reviews; example review:
# ['the', 'rock', 'is', 'destined', 'to', 'be', 'the', '21st', "century's", 'new', '"', 'conan', '"', 'and', 'that', "he's", 'going', 'to', 'make', 'aaaa', 'splash', 'even', 'greater', 'than', 'arnold', 'schwarzenegger', ',', 'jean-claud', 'van', 'damme', 'or', 'steven', 'segal', '.']

# %%
print(f"Test set has {len(test_reviews_ss)} reviews; example review:\n{test_reviews_ls[0]}")
# Out:
# Test set has 100 reviews; example review:
# ['australian', 'actor/director', 'john', 'polson', 'and', 'award-winning', 'english', 'cinematographer', 'giles', 'nuttgens', 'make', 'aaaa', 'terrific', 'effort', 'at', 'disguising', 'the', 'obvious', 'with', 'energy', 'and', 'innovation', '.']

# %% [markdown]
# ## Also add hand-picked reviews from Socher et al, Dhamdhere et al
# #### These are example n-grams used as references in other academic works

# %%
target_vocab_DSA = dict(
    t2dsa = ["wont disappointed", "both inspiring", "aaaa crisp", "excellent youthful", "john terrific"],
)

target_vocab = dict(
    t1 = ['engaging', 'best', 'powerful', 'love', 'beautiful', 'bad', 'dull', 
          'boring', 'fails', 'worst', 'stupid', 'painfully'],
    t2 = ['excellent performances', 'aaaa masterpiece', 'masterful film', 'wonderful movie',
          'marvelous performances', 'worst movie', 'very bad', 'shapeless mess',
          'worst thing', 'instantly forgettable', 'complete failure'],
    t3 = ['an amazing performance', 'wonderful all ages triumph', 'aaaa wonderful movie',
          'most visually stunning', 'for worst movie', 'aaaa lousy movie', 'aaaa complete failure',
          'most painfully marginal', 'very bad sign'],
    t4 = ['gorgeous imagery effective performances', 'just another bad movie',
          'aaaa humorless disjointed mess'],
    t5 = ['nicely acted and beautifully shot', 'the best of the year',
           'aaaa terrific american sports movie', 'refreshingly honest and ultimately touching',
           'silliest and most incoherent movie', 'completely crass and forgettable movie',
           'aaaa cumbersome and cliche ridden movie'],
    t6 = ['aaaa trashy exploitative thoroughly unpleasant experience'],
    t7 = ['aaaa masterful film from aaaa master filmmaker', 'this sloppy drama is an empty vessel',
          'quickly drags on becoming boring and predictable'],
    t8 = ['one of the best films of the year', 'aaaa love for films shines through each frame',
          'created aaaa masterful piece of artistry right here',
          'be the worst special effects creation of the year'],
    t2dsa = ["wont disappointed", "both inspiring", "aaaa crisp", "excellent youthful", "john terrific"],
)

def target_vocab_to_reviews_ss(tv):
    return [' '.join(v) for v in tv.values()]

def target_vocab_DSA_to_reviews_ss(tv):
    return [' '.join(v) for v in tv.values()]

# %% [markdown]
# ## Manage the formats of the reviews

# %% [markdown]
# #### We add some helper functions to convert between our chosen review formats

# %%
def ss_to_oh(reviews_ss, vectorizer):
    oh_reviews = vectorizer.transform(reviews_ss).toarray().astype(bool)
    return pd.DataFrame(
        columns = vectorizer.get_feature_names(), data=oh_reviews
    )    

def ss_to_vc_old(reviews_ss, vectorizer):
    return [
        [vectorizer.get_feature_names().index(w) for w in rev_ss.split()]
        for rev_ss in reviews_ss
    ]

def ss_to_vc(reviews_ss, vectorizer):
    as_oh = ss_to_oh(reviews_ss, vectorizer)
    return [
        [i for i, bl in enumerate(as_oh_row) if bl]
        for as_oh_row in as_oh.values
    ]

# %% [markdown]
# #### A 'vectorizer' is used to encode reviews numerically

# %%
def get_vectorizer(reviews_ss):
    vectorizer = CountVectorizer()
    return vectorizer.fit(reviews_ss)

all_vectorizer = get_vectorizer(
    all_reviews_ss + target_vocab_to_reviews_ss(target_vocab)
)

num_features = len(all_vectorizer.get_feature_names())
print(f"Total vocabulary {num_features}")
# Out:
# Total vocabulary 18326

# %% [markdown]
# #### A function to take the top n most common words from our chosen body of work

# %%
def get_top_n_words(corpus, n):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %% [markdown]
# #### Get the top x words and create a vectorizer of these plus the DSA words

# %%
top_n_words_ss = [
    word for word, _ in get_top_n_words(all_reviews_ss, take_x_most_common_words)
]
    
DSA_vectorizer = get_vectorizer(
    top_n_words_ss + target_vocab_DSA_to_reviews_ss(target_vocab_DSA)
)

num_DSA_features = len(DSA_vectorizer.get_feature_names())

print(f"Total vocabulary {num_DSA_features}")
# Out:
# Total vocabulary 1004

# %% [markdown]
# ## Shuffle the training set

# %%
def get_shuffle_index(x_len):
    return np.random.permutation(np.arange(x_len))

# %%
si = get_shuffle_index(len(train_reviews_ss))
ss_train = [train_reviews_ss[i] for i in si]
train_y = train_y[si]

# %% [markdown]
# #### One-hot encode the (now shuffled) training set

# %%
oh_train = ss_to_oh(ss_train, DSA_vectorizer)

# %% [markdown]
# #### One-hot encode the test set (no shuffling is needed)

# %%
oh_test = ss_to_oh(test_reviews_ss, DSA_vectorizer)

# %% [markdown]
# ## Define the ML model

# %%
model = Sequential()
model.add(Dense(16, input_dim=oh_train.shape[1], activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# #### Train on one-hot encoded data

# %%
model.compile(optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy"])
model.fit(oh_train.values, train_y, epochs=4, batch_size=5)
# Out:
# Epoch 1/4
# 2113/2113 [==============================] - 1s 480us/step - loss: 0.6599 - accuracy: 0.5886
# Epoch 2/4
# 2113/2113 [==============================] - 1s 466us/step - loss: 0.5361 - accuracy: 0.7315
# Epoch 3/4
# 2113/2113 [==============================] - 1s 454us/step - loss: 0.5069 - accuracy: 0.7517
# Epoch 4/4
# 2113/2113 [==============================] - 1s 458us/step - loss: 0.4891 - accuracy: 0.7670

# %%
_, accuracy = model.evaluate(oh_test.values, test_y)
print(f"Model accuracy on test set is {accuracy:.2%}")
# Out:
# 4/4 [==============================] - 0s 853us/step - loss: 0.5024 - accuracy: 0.7800
# Model accuracy on test set is 78.00%

# %% [markdown]
# #### Some examples of incorrect predictions

# %%
predictions = (model.predict(oh_test.values) > 0.5).astype(np.int32)
incorrect_predictions = [
    (rev, predicted[0], actual) 
    for (rev, predicted, actual) in zip(test_reviews_ss, predictions, test_y)
    if predicted[0] != int(actual)
]
for rev, predicted, actual in incorrect_predictions[:3]:
    print(f"{rev}")
    print(f"Predicted {predicted}, actual {int(actual)}\n\n")
# Out:
# this is wild surreal stuff , but brilliant and the camera just kind of sits there and lets you look at this and its like you're going from one room to the next and none of them have any relation to the other .
#
# Predicted 0, actual 1
#
#
# it's aaaa demented kitsch mess ( although the smeary digital video does match the muddled narrative ) , but it's savvy about celebrity and has more guts and energy than much of what will open this year .
#
# Predicted 0, actual 1
#
#
# aaaa movie with aaaa real anarchic flair .
#
# Predicted 0, actual 1

# %% [markdown]
# #### We need a function to generate a powerset of features; but only up to maximum set size of k

# %%
def get_powerset_to_k(seq, k, init=True):
    if init:
        seq = [s if type(s) == frozenset else frozenset([s]) for s in seq]
    if len(seq) <= 1:
        yield seq[0]
        yield frozenset()
    else: 
        for item in get_powerset_to_k(seq[1:], k, False):
            if len(item) <= k - 1:
                yield seq[0].union(item)
            yield item
            
def get_powerset_to_k_ex_emptyset(seq, k):
    gen = get_powerset_to_k(seq, k)
    for item in gen:
        if item != frozenset():
            yield item

# %%
def choose(n, k):
    return scipy.special.comb(n, k)

# %% [markdown]
# #### The q values allow us to probability-weight our sampled results

# %%
def get_q_values_for_k(k, num_local_features):
    q = np.zeros(num_local_features, dtype=np.longdouble) 
    q0den = sum([
        choose(num_local_features, s) for s in range(1, k+1)
    ])
    q[0] = 1/q0den 
    for r in range(1, num_local_features):
        limd = min(k, (num_local_features - r))
        limn = max((r - k), 0)
        qden = sum([
            choose(num_local_features - r, s) for s in range(1, limd+1)
        ])
        qnum = sum([
            choose(r, s) * q[s] for s in range(limn, r)
        ])
        q[r] = qnum / qden
    # Check that the checksum is satisfied
    checksum = sum([
        choose(num_local_features, i) * q[i] 
        for i in range((num_local_features - k), num_local_features)
    ])
    assert(np.isclose(checksum, 1.0))
    return q

_all_q_values = [get_q_values_for_k(_k, num_DSA_features) for _k in range(1, k+1)]
q_values = np.vstack(_all_q_values)

# %% [markdown]
# ### Take a single sample review

# %%
sample_review_oh = oh_test.iloc[0]
print(f'sample review: {test_reviews_ss[0]}')
all_features_set = set(range(1, num_DSA_features + 1))
# Out:
# sample review: australian actor/director john polson and award-winning english cinematographer giles nuttgens make aaaa terrific effort at disguising the obvious with energy and innovation .

# %% [markdown]
# ## The Joint Shapley calculation function

# %%
def calculate_phi_t(
    review_oh,
    value_function,
    coalition_vc,
    num_features,
    q_values,
    num_sampling_iterations,
):
    coalition_size = len(coalition_vc)
    p_values = np.zeros((num_features - coalition_size + 1), dtype=np.longdouble)
    for i in range(1, num_features - coalition_size + 2):
        q_value = q_values[k-1, i-1]
        num_ft_choose_len = choose((num_features - coalition_size), (i - 1))
        p_values[i - 1] = num_ft_choose_len * q_value
    hat_p_values = p_values / np.sum(p_values)
    estimates = np.zeros(num_sampling_iterations)

    for itr in range(0, num_sampling_iterations):
        U = np.random.uniform(0, 1, 1)
        X = sum(U > hat_p_values.cumsum())
        S = set()
        for w in range(1, X + 1):
            possible_next = set(range(1, num_features + 1)).difference(
                set(coalition_vc).union(S))
            r = random.sample(possible_next, 1)
            S = S.union(set(r))

        z = np.random.randint(0, 2, num_features)
        xminusT = np.copy(review_oh)
        xplusT = np.copy(review_oh)
        for h in set(range(0, num_features)).difference(S):
            xminusT[h] = z[h]
        for h in set(range(0, num_features)).difference(S.union(set(coalition_vc))):
            xplusT[h] = z[h]

        estimates[itr] = value_function(xplusT) - value_function(xminusT)
    return np.mean(estimates) * np.sum(p_values)

# %% [markdown]
# #### We use a 'value function' to give us the value of a given coalition; in this case the 'value' is the prediction it receives from our ML model

# %%
value_f = lambda oh: model.predict(oh[None, :])[0][0]

# %% [markdown]
# #### We look at our target vocabulary, from Socher et al and DSA

# %%
# Obtain bigrams used in Dhamdhere et al as strings
t2dsa = target_vocab["t2dsa"]
# Vectorize bigrams
t2dsa_vc = ss_to_vc(t2dsa, DSA_vectorizer)
# Add both bigrams and single words from bigrams to list of coalitions
DSA_coalitions = [cln for cln in t2dsa_vc] + [[word] for cln in t2dsa_vc for word in cln]

# %% [markdown]
# #### We can now calculate Joint Shapley values for the Dhamdhere et al coalitions

# %%
test_reviews_vc = ss_to_vc(test_reviews_ss, DSA_vectorizer)
num_review = 38 # sets the review to be analysed
sample_review_oh = oh_test.iloc[num_review]
print(f'test_reviews_vc[num_review] = {test_reviews_vc[num_review]}')

num_times_to_loop = 60

with open("results/250528-review-38-convergence.txt", "a") as a_writer:
    a_writer.write(f'test_reviews_vc[num_review] = {test_reviews_vc[num_review]}\n')

    for loop_num in range(num_times_to_loop+1):
        a_writer.write(f'loop number = {loop_num}\n')
        for coalition in DSA_coalitions:
            js = calculate_phi_t(
                sample_review_oh,
                value_f,
                coalition,
                num_DSA_features,
                q_values,
                num_sampling_iterations
            )
            a_writer.write(f'k = {k}, coalition {coalition}: local jShapley = {js}\n')
# Out:
# test_reviews_vc[num_review] = [44, 101, 434, 447, 677, 860, 946]

# %% [markdown]
# #### Iterate through all the reviews in the test set, calculating local Joint Shapleys for the DSA features

# %%
for n, review_oh in enumerate(oh_test.iloc):
    for coalition in DSA_coalitions:
        js = calculate_phi_t(
            review_oh,
            value_f,
            coalition,
            num_DSA_features,
            q_values,
            num_sampling_iterations
        )
        print(f'k = {k}, review {n}, coalition {coalition}: local jShapley = {js}')
# Out:
# k = 2, review 0, coalition [209, 978]: local jShapley = -1.4536792479434422e-05
# k = 2, review 0, coalition [101, 434]: local jShapley = -2.6261929950256325e-05
# k = 2, review 0, coalition [3, 174]: local jShapley = -3.5400720296794657e-11
# k = 2, review 0, coalition [269, 1003]: local jShapley = -3.3662190923019074e-06
# k = 2, review 0, coalition [455, 848]: local jShapley = -7.667796016285722e-08
# k = 2, review 0, coalition [209]: local jShapley = 7.586823181546724e-05
# k = 2, review 0, coalition [978]: local jShapley = -0.00011701161234277151
# k = 2, review 0, coalition [101]: local jShapley = -0.00032251380209730797
# k = 2, review 0, coalition [434]: local jShapley = -5.3950716090245555e-06
# k = 2, review 0, coalition [3]: local jShapley = -5.924625644474126e-06
# k = 2, review 0, coalition [174]: local jShapley = 3.1390724837718088e-06
# k = 2, review 0, coalition [269]: local jShapley = -0.0001072492479944602
# k = 2, review 0, coalition [1003]: local jShapley = -6.350541801654e-05
# k = 2, review 0, coalition [455]: local jShapley = -0.00034064934337077284
# k = 2, review 0, coalition [848]: local jShapley = 0.00038255852606981197
# k = 2, review 1, coalition [209, 978]: local jShapley = -1.490370324495055e-08
# k = 2, review 1, coalition [101, 434]: local jShapley = -1.9325253210020203e-07
# k = 2, review 1, coalition [3, 174]: local jShapley = 2.3142571880824067e-06
# k = 2, review 1, coalition [269, 1003]: local jShapley = -5.284154006433604e-05
# k = 2, review 1, coalition [455, 848]: local jShapley = -2.1963196884136352e-07
# k = 2, review 1, coalition [209]: local jShapley = 0.00011498090182834822
# k = 2, review 1, coalition [978]: local jShapley = -0.00015603583855878324
# k = 2, review 1, coalition [101]: local jShapley = -0.0004039730550138992
# k = 2, review 1, coalition [434]: local jShapley = -5.416086605696286e-05
# k = 2, review 1, coalition [3]: local jShapley = -4.1339159443132017e-07
# k = 2, review 1, coalition [174]: local jShapley = 1.4707853738000152e-05
# k = 2, review 1, coalition [269]: local jShapley = -9.239809599948271e-05
# k = 2, review 1, coalition [1003]: local jShapley = -6.499459151242778e-05
# k = 2, review 1, coalition [455]: local jShapley = 0.00041473803823187464
# k = 2, review 1, coalition [848]: local jShapley = -0.00014788348680608833
# k = 2, review 2, coalition [209, 978]: local jShapley = 1.1338119096177196e-05
# k = 2, review 2, coalition [101, 434]: local jShapley = -1.4007268505234968e-05
# k = 2, review 2, coalition [3, 174]: local jShapley = 2.1240432178076794e-10
# k = 2, review 2, coalition [269, 1003]: local jShapley = -1.136489384096167e-05
# k = 2, review 2, coalition [455, 848]: local jShapley = -1.805153529374153e-06
# k = 2, review 2, coalition [209]: local jShapley = 0.0001233950455140134
# k = 2, review 2, coalition [978]: local jShapley = -2.061414243326802e-06
# k = 2, review 2, coalition [101]: local jShapley = -3.411525433722469e-10
# k = 2, review 2, coalition [434]: local jShapley = -5.767993982998343e-06
# k = 2, review 2, coalition [3]: local jShapley = 3.8593137333392964e-05
# k = 2, review 2, coalition [174]: local jShapley = 9.346726807041135e-06
# k = 2, review 2, coalition [269]: local jShapley = -4.023246059243245e-05
# k = 2, review 2, coalition [1003]: local jShapley = -3.65706144800106e-05
# k = 2, review 2, coalition [455]: local jShapley = 0.00028695918253552786
# k = 2, review 2, coalition [848]: local jShapley = -4.290163809177691e-06
# k = 2, review 3, coalition [209, 978]: local jShapley = -7.126265297785605e-06
# k = 2, review 3, coalition [101, 434]: local jShapley = -9.877036967607688e-06
# k = 2, review 3, coalition [3, 174]: local jShapley = 3.689168063329466e-07
# k = 2, review 3, coalition [269, 1003]: local jShapley = -7.929761346482004e-09
# k = 2, review 3, coalition [455, 848]: local jShapley = -1.770454923363245e-05
# k = 2, review 3, coalition [209]: local jShapley = 7.918905331672063e-05
# k = 2, review 3, coalition [978]: local jShapley = -0.00012849425257979838
# k = 2, review 3, coalition [101]: local jShapley = -0.00020945981512206203
# k = 2, review 3, coalition [434]: local jShapley = -2.9137710797219842e-05
# k = 2, review 3, coalition [3]: local jShapley = -4.81771357343495e-05
# k = 2, review 3, coalition [174]: local jShapley = 8.852908500509807e-08
# k = 2, review 3, coalition [269]: local jShapley = -0.0005018123635038976
# k = 2, review 3, coalition [1003]: local jShapley = -6.171829041808449e-05
# k = 2, review 3, coalition [455]: local jShapley = 0.0003258417025138363
# k = 2, review 3, coalition [848]: local jShapley = -0.0002835931583222776
# k = 2, review 4, coalition [209, 978]: local jShapley = 0.0
# k = 2, review 4, coalition [101, 434]: local jShapley = -8.142165668262772e-10
# k = 2, review 4, coalition [3, 174]: local jShapley = 4.342134349203843e-07
# k = 2, review 4, coalition [269, 1003]: local jShapley = 0.0
# k = 2, review 4, coalition [455, 848]: local jShapley = 2.905219112356948e-08
# k = 2, review 4, coalition [209]: local jShapley = 6.504947442784279e-05
# k = 2, review 4, coalition [978]: local jShapley = -0.00024548484139708457
# k = 2, review 4, coalition [101]: local jShapley = -0.00015892399334690476
# k = 2, review 4, coalition [434]: local jShapley = -1.622342391193136e-05
# k = 2, review 4, coalition [3]: local jShapley = 4.616275789794014e-05
# k = 2, review 4, coalition [174]: local jShapley = 1.4919453603026788e-06
# k = 2, review 4, coalition [269]: local jShapley = -0.00023614608903074476
# k = 2, review 4, coalition [1003]: local jShapley = -3.4149113727154384e-05
# k = 2, review 4, coalition [455]: local jShapley = 0.0007615468481291655
# k = 2, review 4, coalition [848]: local jShapley = -0.0003730439948554996
# k = 2, review 5, coalition [209, 978]: local jShapley = 4.614660894288668e-06
# k = 2, review 5, coalition [101, 434]: local jShapley = -7.164539966558495e-05
# k = 2, review 5, coalition [3, 174]: local jShapley = 3.0582682264400904e-07
# k = 2, review 5, coalition [269, 1003]: local jShapley = -1.6791812462220194e-05
# k = 2, review 5, coalition [455, 848]: local jShapley = 1.4703099163268714e-08
# k = 2, review 5, coalition [209]: local jShapley = 0.0
# k = 2, review 5, coalition [978]: local jShapley = -0.00019328244680348594
# k = 2, review 5, coalition [101]: local jShapley = -0.0001704430516179366
# k = 2, review 5, coalition [434]: local jShapley = -2.519202576871228e-05
# k = 2, review 5, coalition [3]: local jShapley = -3.094219453131942e-05
# k = 2, review 5, coalition [174]: local jShapley = 1.1480763898038304e-05
# k = 2, review 5, coalition [269]: local jShapley = -0.00043221332140171045
# k = 2, review 5, coalition [1003]: local jShapley = -6.476525171514578e-06
# k = 2, review 5, coalition [455]: local jShapley = 0.0002772871241343133
# k = 2, review 5, coalition [848]: local jShapley = -0.000636635592780202
# k = 2, review 6, coalition [209, 978]: local jShapley = -1.7478515634537416e-07
# k = 2, review 6, coalition [101, 434]: local jShapley = -2.0420362692161444e-05
# k = 2, review 6, coalition [3, 174]: local jShapley = -1.6756340940482804e-09
# k = 2, review 6, coalition [269, 1003]: local jShapley = -4.186981252311062e-05
# k = 2, review 6, coalition [455, 848]: local jShapley = 3.0377358086679496e-07
# k = 2, review 6, coalition [209]: local jShapley = 0.0001905814141854041
# k = 2, review 6, coalition [978]: local jShapley = -0.0002004672046550413
# k = 2, review 6, coalition [101]: local jShapley = -0.00026875605041440734
# k = 2, review 6, coalition [434]: local jShapley = -1.3219661055674567e-08
# k = 2, review 6, coalition [3]: local jShapley = -5.3555618800952575e-05
# k = 2, review 6, coalition [174]: local jShapley = 5.291224774822044e-05
# k = 2, review 6, coalition [269]: local jShapley = -0.001065178709832178
# k = 2, review 6, coalition [1003]: local jShapley = -1.0417860505094147e-05
# k = 2, review 6, coalition [455]: local jShapley = 0.0005075089713171952
# k = 2, review 6, coalition [848]: local jShapley = -0.0010963762996862795
# k = 2, review 7, coalition [209, 978]: local jShapley = 1.4550817064792003e-05
# k = 2, review 7, coalition [101, 434]: local jShapley = -2.3600480197863105e-11
# k = 2, review 7, coalition [3, 174]: local jShapley = -3.855315443922422e-06
# k = 2, review 7, coalition [269, 1003]: local jShapley = -7.080144059358931e-11
# k = 2, review 7, coalition [455, 848]: local jShapley = 4.632691661159835e-06
# k = 2, review 7, coalition [209]: local jShapley = 1.0571464437747501e-05
# k = 2, review 7, coalition [978]: local jShapley = -4.053693923739218e-05
# k = 2, review 7, coalition [101]: local jShapley = -1.3953224312060742e-05
# k = 2, review 7, coalition [434]: local jShapley = -5.331617235957318e-06
# k = 2, review 7, coalition [3]: local jShapley = -1.153692613549096e-06
# k = 2, review 7, coalition [174]: local jShapley = 1.6169777674486074e-06
# k = 2, review 7, coalition [269]: local jShapley = -1.5839456724365896e-05
# k = 2, review 7, coalition [1003]: local jShapley = -4.3846374772510504e-05
# k = 2, review 7, coalition [455]: local jShapley = 1.0012230131024544e-05
# k = 2, review 7, coalition [848]: local jShapley = -9.66886009612038e-06
# k = 2, review 8, coalition [209, 978]: local jShapley = 1.4299424749724365e-05
# k = 2, review 8, coalition [101, 434]: local jShapley = -1.078376741680959e-06
# k = 2, review 8, coalition [3, 174]: local jShapley = -1.2306470399175716e-07
# k = 2, review 8, coalition [269, 1003]: local jShapley = -1.6009137937178358e-05
# k = 2, review 8, coalition [455, 848]: local jShapley = -4.719482427087477e-06
# k = 2, review 8, coalition [209]: local jShapley = 0.0001244774372459977
# k = 2, review 8, coalition [978]: local jShapley = -0.0001237089911420517
# k = 2, review 8, coalition [101]: local jShapley = -6.033965034624931e-06
# k = 2, review 8, coalition [434]: local jShapley = -3.06880358865071e-05
# k = 2, review 8, coalition [3]: local jShapley = -4.5924846643005916e-05
# k = 2, review 8, coalition [174]: local jShapley = 3.567602722315272e-07
# k = 2, review 8, coalition [269]: local jShapley = -0.000411893423037101
# k = 2, review 8, coalition [1003]: local jShapley = -4.267118954872896e-05
# k = 2, review 8, coalition [455]: local jShapley = 0.00035382175479919037
# k = 2, review 8, coalition [848]: local jShapley = -0.000399692955204751
# k = 2, review 9, coalition [209, 978]: local jShapley = -4.526678304111034e-06
# k = 2, review 9, coalition [101, 434]: local jShapley = -4.0458969916762314e-05
# k = 2, review 9, coalition [3, 174]: local jShapley = -2.088642497510885e-09
# k = 2, review 9, coalition [269, 1003]: local jShapley = -1.4187782678148371e-06
# k = 2, review 9, coalition [455, 848]: local jShapley = -9.019672822859668e-06
# k = 2, review 9, coalition [209]: local jShapley = 8.025907826900767e-05
# k = 2, review 9, coalition [978]: local jShapley = -0.00020418414690321778
# k = 2, review 9, coalition [101]: local jShapley = -0.00047350706491250605
# k = 2, review 9, coalition [434]: local jShapley = -3.8036035230066084e-05
# k = 2, review 9, coalition [3]: local jShapley = -9.001821585691794e-06
# k = 2, review 9, coalition [174]: local jShapley = -2.5495992684856952e-05
# k = 2, review 9, coalition [269]: local jShapley = -0.000238482813376573
# k = 2, review 9, coalition [1003]: local jShapley = -7.456400564215515e-05
# k = 2, review 9, coalition [455]: local jShapley = 4.0273057745093745e-07
# k = 2, review 9, coalition [848]: local jShapley = -5.781563325410975e-05
# k = 2, review 10, coalition [209, 978]: local jShapley = 2.092178383206606e-06
# k = 2, review 10, coalition [101, 434]: local jShapley = -1.4008065021441647e-06
# k = 2, review 10, coalition [3, 174]: local jShapley = -5.353096319199606e-06
# k = 2, review 10, coalition [269, 1003]: local jShapley = -4.0053903074886286e-05
# k = 2, review 10, coalition [455, 848]: local jShapley = -2.263107867349578e-05
# k = 2, review 10, coalition [209]: local jShapley = 0.00017819100967453162
# k = 2, review 10, coalition [978]: local jShapley = -0.0003302728049674947
# k = 2, review 10, coalition [101]: local jShapley = -0.00041762265356235867
# k = 2, review 10, coalition [434]: local jShapley = -2.0802842433820794e-05
# k = 2, review 10, coalition [3]: local jShapley = -0.00012010279553826743
# k = 2, review 10, coalition [174]: local jShapley = 0.0
# k = 2, review 10, coalition [269]: local jShapley = -0.0009803567162955666
# k = 2, review 10, coalition [1003]: local jShapley = -3.083507263270054e-05
# k = 2, review 10, coalition [455]: local jShapley = 0.0006232075301645949
# k = 2, review 10, coalition [848]: local jShapley = -0.0003069613825941219
# k = 2, review 11, coalition [209, 978]: local jShapley = 1.0222654199865293e-05
# k = 2, review 11, coalition [101, 434]: local jShapley = 5.3531789208802987e-08
# k = 2, review 11, coalition [3, 174]: local jShapley = -6.548136134618652e-06
# k = 2, review 11, coalition [269, 1003]: local jShapley = -3.227609932027827e-05
# k = 2, review 11, coalition [455, 848]: local jShapley = 2.234989075217834e-06
# k = 2, review 11, coalition [209]: local jShapley = 0.0002953408740855047
# k = 2, review 11, coalition [978]: local jShapley = -4.152508757926989e-05
# k = 2, review 11, coalition [101]: local jShapley = -0.0001186489313306187
# k = 2, review 11, coalition [434]: local jShapley = -5.099462930192504e-06
# k = 2, review 11, coalition [3]: local jShapley = -0.00010102251758406897
# k = 2, review 11, coalition [174]: local jShapley = -4.22539599881847e-05
# k = 2, review 11, coalition [269]: local jShapley = -0.00022777015442993726
# k = 2, review 11, coalition [1003]: local jShapley = -3.2751411756958294e-05
# k = 2, review 11, coalition [455]: local jShapley = 0.0008235678261413569
# k = 2, review 11, coalition [848]: local jShapley = 0.0
# k = 2, review 12, coalition [209, 978]: local jShapley = -5.426741617657038e-06
# k = 2, review 12, coalition [101, 434]: local jShapley = -1.2901237900882163e-05
# k = 2, review 12, coalition [3, 174]: local jShapley = 1.4988428968860879e-06
# k = 2, review 12, coalition [269, 1003]: local jShapley = -3.5610705569355145e-05
# k = 2, review 12, coalition [455, 848]: local jShapley = -1.5682519091480033e-08
# k = 2, review 12, coalition [209]: local jShapley = 0.0001475263427372455
# k = 2, review 12, coalition [978]: local jShapley = -8.472604438378803e-05
# k = 2, review 12, coalition [101]: local jShapley = -0.00019550352043711094
# k = 2, review 12, coalition [434]: local jShapley = -4.540889606522332e-05
# k = 2, review 12, coalition [3]: local jShapley = -1.543113977401724e-05
# k = 2, review 12, coalition [174]: local jShapley = 1.529723740074363e-05
# k = 2, review 12, coalition [269]: local jShapley = -8.796814493565826e-05
# k = 2, review 12, coalition [1003]: local jShapley = 2.1611160741273413e-06
# k = 2, review 12, coalition [455]: local jShapley = 0.0005166307506659503
# k = 2, review 12, coalition [848]: local jShapley = -1.6665301743734263e-07
# k = 2, review 13, coalition [209, 978]: local jShapley = 1.3098266509814022e-09
# k = 2, review 13, coalition [101, 434]: local jShapley = -7.254197600818171e-08
# k = 2, review 13, coalition [3, 174]: local jShapley = 1.2320807690895918e-06
# k = 2, review 13, coalition [269, 1003]: local jShapley = -4.8922910432162796e-05
# k = 2, review 13, coalition [455, 848]: local jShapley = 2.121507936222424e-05
# k = 2, review 13, coalition [209]: local jShapley = 3.866494994377282e-06
# k = 2, review 13, coalition [978]: local jShapley = -1.5111351908673677e-06
# k = 2, review 13, coalition [101]: local jShapley = -2.80645301839066e-05
# k = 2, review 13, coalition [434]: local jShapley = -2.3607756001359488e-07
# k = 2, review 13, coalition [3]: local jShapley = 1.0757596249803776e-05
# k = 2, review 13, coalition [174]: local jShapley = 1.965784921012769e-05
# k = 2, review 13, coalition [269]: local jShapley = -0.00013773159735262078
# k = 2, review 13, coalition [1003]: local jShapley = -1.2593902002994023e-05
# k = 2, review 13, coalition [455]: local jShapley = 0.0
# k = 2, review 13, coalition [848]: local jShapley = -5.7539271458941066e-05
# k = 2, review 14, coalition [209, 978]: local jShapley = -5.86418831836453e-07
# k = 2, review 14, coalition [101, 434]: local jShapley = -4.264016759748916e-07
# k = 2, review 14, coalition [3, 174]: local jShapley = 3.763539076552982e-06
# k = 2, review 14, coalition [269, 1003]: local jShapley = -5.4637117698869906e-06
# k = 2, review 14, coalition [455, 848]: local jShapley = 6.749146144559892e-05
# k = 2, review 14, coalition [209]: local jShapley = 0.00020475711259981146
# k = 2, review 14, coalition [978]: local jShapley = -1.6421377675223106e-06
# k = 2, review 14, coalition [101]: local jShapley = -0.0006377397329868263
# k = 2, review 14, coalition [434]: local jShapley = -8.290774397168187e-06
# k = 2, review 14, coalition [3]: local jShapley = 6.134050662036764e-06
# k = 2, review 14, coalition [174]: local jShapley = 1.19107440348911e-05
# k = 2, review 14, coalition [269]: local jShapley = -0.0005737449316468189
# k = 2, review 14, coalition [1003]: local jShapley = -2.1701011792384077e-05
# k = 2, review 14, coalition [455]: local jShapley = 0.0003807147245050887
# k = 2, review 14, coalition [848]: local jShapley = -0.001358918427099433
# k = 2, review 15, coalition [209, 978]: local jShapley = -8.164562523970543e-06
# k = 2, review 15, coalition [101, 434]: local jShapley = -3.776076831658097e-09
# k = 2, review 15, coalition [3, 174]: local jShapley = 2.142947202446168e-06
# k = 2, review 15, coalition [269, 1003]: local jShapley = -3.4291497727495094e-08
# k = 2, review 15, coalition [455, 848]: local jShapley = 2.1800943582776043e-05
# k = 2, review 15, coalition [209]: local jShapley = 0.000202709642966695
# k = 2, review 15, coalition [978]: local jShapley = -0.00036020659522467365
# k = 2, review 15, coalition [101]: local jShapley = -0.00011849268346575421
# k = 2, review 15, coalition [434]: local jShapley = -7.87950647731936e-05
# k = 2, review 15, coalition [3]: local jShapley = -7.556000049253043e-05
# k = 2, review 15, coalition [174]: local jShapley = -1.997789293987878e-06
# k = 2, review 15, coalition [269]: local jShapley = -0.00026208600646266485
# k = 2, review 15, coalition [1003]: local jShapley = -4.6693079526612294e-05
# k = 2, review 15, coalition [455]: local jShapley = 0.0003769781659856684
# k = 2, review 15, coalition [848]: local jShapley = -0.0004395586341689904
# k = 2, review 16, coalition [209, 978]: local jShapley = -4.115062328980103e-06
# k = 2, review 16, coalition [101, 434]: local jShapley = 0.0
# k = 2, review 16, coalition [3, 174]: local jShapley = -9.98028906847334e-07
# k = 2, review 16, coalition [269, 1003]: local jShapley = -6.424758724264273e-07
# k = 2, review 16, coalition [455, 848]: local jShapley = -4.581915228014133e-06
# k = 2, review 16, coalition [209]: local jShapley = 0.00011743587817452284
# k = 2, review 16, coalition [978]: local jShapley = -4.901952665207141e-05
# k = 2, review 16, coalition [101]: local jShapley = -1.4831692111244276e-05
# k = 2, review 16, coalition [434]: local jShapley = 4.857159336262365e-07
# k = 2, review 16, coalition [3]: local jShapley = -1.702351191427512e-07
# k = 2, review 16, coalition [174]: local jShapley = 1.063884206506352e-06
# k = 2, review 16, coalition [269]: local jShapley = -0.00022218181990509234
# k = 2, review 16, coalition [1003]: local jShapley = -1.5215403434402213e-07
# k = 2, review 16, coalition [455]: local jShapley = 0.0001640328806161079
# k = 2, review 16, coalition [848]: local jShapley = -1.4320048584321752e-05
# k = 2, review 17, coalition [209, 978]: local jShapley = -6.884796984641169e-06
# k = 2, review 17, coalition [101, 434]: local jShapley = -7.034395902693257e-07
# k = 2, review 17, coalition [3, 174]: local jShapley = 9.355348352833924e-06
# k = 2, review 17, coalition [269, 1003]: local jShapley = -2.7494583030990716e-05
# k = 2, review 17, coalition [455, 848]: local jShapley = 8.052566445191583e-06
# k = 2, review 17, coalition [209]: local jShapley = 0.00014098414570113177
# k = 2, review 17, coalition [978]: local jShapley = -0.0001579533717169428
# k = 2, review 17, coalition [101]: local jShapley = -0.000354255615546224
# k = 2, review 17, coalition [434]: local jShapley = -4.231698792057272e-06
# k = 2, review 17, coalition [3]: local jShapley = 6.502529524133127e-05
# k = 2, review 17, coalition [174]: local jShapley = 1.595301787724093e-05
# k = 2, review 17, coalition [269]: local jShapley = -0.00045786052995141715
# k = 2, review 17, coalition [1003]: local jShapley = -5.163514320210643e-05
# k = 2, review 17, coalition [455]: local jShapley = 7.713505914121216e-05
# k = 2, review 17, coalition [848]: local jShapley = -0.0007686049530989939
# k = 2, review 18, coalition [209, 978]: local jShapley = -2.3258273234994088e-08
# k = 2, review 18, coalition [101, 434]: local jShapley = -1.5153927336248394e-06
# k = 2, review 18, coalition [3, 174]: local jShapley = 3.11526338611793e-08
# k = 2, review 18, coalition [269, 1003]: local jShapley = -1.4912671427425738e-05
# k = 2, review 18, coalition [455, 848]: local jShapley = 1.9519284557966932e-05
# k = 2, review 18, coalition [209]: local jShapley = 0.00013970119891771254
# k = 2, review 18, coalition [978]: local jShapley = -5.500419514417905e-05
# k = 2, review 18, coalition [101]: local jShapley = -0.00027066258140304313
# k = 2, review 18, coalition [434]: local jShapley = -8.778281381647129e-06
# k = 2, review 18, coalition [3]: local jShapley = -4.8302722514378404e-05
# k = 2, review 18, coalition [174]: local jShapley = 2.5635268210688672e-05
# k = 2, review 18, coalition [269]: local jShapley = -0.0001298975835669601
# k = 2, review 18, coalition [1003]: local jShapley = 0.0
# k = 2, review 18, coalition [455]: local jShapley = 0.0005595601074018762
# k = 2, review 18, coalition [848]: local jShapley = 0.00048091847598506434
# k = 2, review 19, coalition [209, 978]: local jShapley = 2.556706691191069e-05
# k = 2, review 19, coalition [101, 434]: local jShapley = -1.1800240098931553e-11
# k = 2, review 19, coalition [3, 174]: local jShapley = 1.5398723317100728e-07
# k = 2, review 19, coalition [269, 1003]: local jShapley = -2.4414696764689383e-08
# k = 2, review 19, coalition [455, 848]: local jShapley = 1.0987203556115168e-07
# k = 2, review 19, coalition [209]: local jShapley = 0.0001166590311891963
# k = 2, review 19, coalition [978]: local jShapley = -0.0004019871207707935
# k = 2, review 19, coalition [101]: local jShapley = -0.00036507415971350887
# k = 2, review 19, coalition [434]: local jShapley = -1.774470839096405e-05
# k = 2, review 19, coalition [3]: local jShapley = 1.8366885341939185e-05
# k = 2, review 19, coalition [174]: local jShapley = 3.165469161815236e-06
# k = 2, review 19, coalition [269]: local jShapley = -6.649028955070756e-05
# k = 2, review 19, coalition [1003]: local jShapley = 0.0
# k = 2, review 19, coalition [455]: local jShapley = 0.0004925107541207174
# k = 2, review 19, coalition [848]: local jShapley = -0.00045583105611496355
# k = 2, review 20, coalition [209, 978]: local jShapley = 7.260687732872584e-08
# k = 2, review 20, coalition [101, 434]: local jShapley = -1.3478741651323873e-05
# k = 2, review 20, coalition [3, 174]: local jShapley = 2.9730704929258044e-08
# k = 2, review 20, coalition [269, 1003]: local jShapley = -3.019463136874754e-05
# k = 2, review 20, coalition [455, 848]: local jShapley = -5.050042552978846e-06
# k = 2, review 20, coalition [209]: local jShapley = 4.301195829548991e-05
# k = 2, review 20, coalition [978]: local jShapley = -0.0001600419502315356
# k = 2, review 20, coalition [101]: local jShapley = -0.0002633254136527362
# k = 2, review 20, coalition [434]: local jShapley = -3.1741685516712283e-06
# k = 2, review 20, coalition [3]: local jShapley = 8.90173595827996e-06
# k = 2, review 20, coalition [174]: local jShapley = 3.142484009205531e-05
# k = 2, review 20, coalition [269]: local jShapley = -0.0002458857382796149
# k = 2, review 20, coalition [1003]: local jShapley = -1.0195429046815443e-05
# k = 2, review 20, coalition [455]: local jShapley = 0.0007247726508688976
# k = 2, review 20, coalition [848]: local jShapley = -0.0003932947671860083
# k = 2, review 21, coalition [209, 978]: local jShapley = -2.576688627762595e-06
# k = 2, review 21, coalition [101, 434]: local jShapley = -1.4150847926638717e-07
# k = 2, review 21, coalition [3, 174]: local jShapley = 1.400458395061246e-06
# k = 2, review 21, coalition [269, 1003]: local jShapley = -2.28318125578187e-06
# k = 2, review 21, coalition [455, 848]: local jShapley = -3.2128047607877027e-05
# k = 2, review 21, coalition [209]: local jShapley = 7.83328030769242e-05
# k = 2, review 21, coalition [978]: local jShapley = -3.093665080248962e-05
# k = 2, review 21, coalition [101]: local jShapley = -0.0001337335880527735
# k = 2, review 21, coalition [434]: local jShapley = -3.2079852975330026e-05
# k = 2, review 21, coalition [3]: local jShapley = 2.262839233747361e-05
# k = 2, review 21, coalition [174]: local jShapley = -1.0024426334450103e-05
# k = 2, review 21, coalition [269]: local jShapley = -7.442677703158367e-05
# k = 2, review 21, coalition [1003]: local jShapley = -8.39277900763649e-06
# k = 2, review 21, coalition [455]: local jShapley = 0.00019442087284071913
# k = 2, review 21, coalition [848]: local jShapley = -1.8744626495588106e-05
# k = 2, review 22, coalition [209, 978]: local jShapley = 1.119724782987615e-07
# k = 2, review 22, coalition [101, 434]: local jShapley = -1.2630977001896336e-07
# k = 2, review 22, coalition [3, 174]: local jShapley = 4.164422733313934e-07
# k = 2, review 22, coalition [269, 1003]: local jShapley = -4.5301121739798224e-08
# k = 2, review 22, coalition [455, 848]: local jShapley = 2.6034869730272683e-07
# k = 2, review 22, coalition [209]: local jShapley = 0.00016898607439332956
# k = 2, review 22, coalition [978]: local jShapley = -0.00013567986331271216
# k = 2, review 22, coalition [101]: local jShapley = -0.0002318579721368273
# k = 2, review 22, coalition [434]: local jShapley = -1.853080913902955e-05
# k = 2, review 22, coalition [3]: local jShapley = 5.913367610542841e-06
# k = 2, review 22, coalition [174]: local jShapley = 4.1707817410313656e-05
# k = 2, review 22, coalition [269]: local jShapley = -4.150427727412419e-05
# k = 2, review 22, coalition [1003]: local jShapley = -7.745407941333314e-05
# k = 2, review 22, coalition [455]: local jShapley = 0.0009995924745214069
# k = 2, review 22, coalition [848]: local jShapley = -0.0013315092935954126
# k = 2, review 23, coalition [209, 978]: local jShapley = -3.593444515646933e-06
# k = 2, review 23, coalition [101, 434]: local jShapley = -3.206855079729821e-05
# k = 2, review 23, coalition [3, 174]: local jShapley = 1.7733164815872357e-06
# k = 2, review 23, coalition [269, 1003]: local jShapley = -6.709620060324511e-05
# k = 2, review 23, coalition [455, 848]: local jShapley = -4.986707124295851e-05
# k = 2, review 23, coalition [209]: local jShapley = 6.740730758729216e-05
# k = 2, review 23, coalition [978]: local jShapley = -6.2338633674139e-05
# k = 2, review 23, coalition [101]: local jShapley = -0.0006518460068586574
# k = 2, review 23, coalition [434]: local jShapley = -5.5580017993323485e-05
# k = 2, review 23, coalition [3]: local jShapley = 6.568167273477948e-06
# k = 2, review 23, coalition [174]: local jShapley = -2.6837361841328707e-05
# k = 2, review 23, coalition [269]: local jShapley = -3.5045833187408336e-05
# k = 2, review 23, coalition [1003]: local jShapley = -2.8671952287380886e-05
# k = 2, review 23, coalition [455]: local jShapley = 0.0007115329044572318
# k = 2, review 23, coalition [848]: local jShapley = -0.000246228596585704
# k = 2, review 24, coalition [209, 978]: local jShapley = 1.4102348939832108e-06
# k = 2, review 24, coalition [101, 434]: local jShapley = -9.319328119931936e-06
# k = 2, review 24, coalition [3, 174]: local jShapley = 1.2802080483330843e-07
# k = 2, review 24, coalition [269, 1003]: local jShapley = -4.7215120683844926e-07
# k = 2, review 24, coalition [455, 848]: local jShapley = 7.775178201186e-07
# k = 2, review 24, coalition [209]: local jShapley = 0.00013200944574263807
# k = 2, review 24, coalition [978]: local jShapley = -0.00021553416408900868
# k = 2, review 24, coalition [101]: local jShapley = -0.0002963885535462009
# k = 2, review 24, coalition [434]: local jShapley = -3.167008612667204e-05
# k = 2, review 24, coalition [3]: local jShapley = 3.5241057730353107e-07
# k = 2, review 24, coalition [174]: local jShapley = -1.2762388715351993e-05
# k = 2, review 24, coalition [269]: local jShapley = -0.00038261767339201915
# k = 2, review 24, coalition [1003]: local jShapley = -9.74477933024108e-05
# k = 2, review 24, coalition [455]: local jShapley = 0.0008312333958587275
# k = 2, review 24, coalition [848]: local jShapley = -0.00044866975250076505
# k = 2, review 25, coalition [209, 978]: local jShapley = -2.9523020703516853e-07
# k = 2, review 25, coalition [101, 434]: local jShapley = -1.8081649506474007e-05
# k = 2, review 25, coalition [3, 174]: local jShapley = 1.1800240098931553e-11
# k = 2, review 25, coalition [269, 1003]: local jShapley = -3.404322067581357e-06
# k = 2, review 25, coalition [455, 848]: local jShapley = 1.259557628159954e-07
# k = 2, review 25, coalition [209]: local jShapley = 0.0
# k = 2, review 25, coalition [978]: local jShapley = -4.399844351871868e-06
# k = 2, review 25, coalition [101]: local jShapley = -3.74414916351041e-08
# k = 2, review 25, coalition [434]: local jShapley = -8.820754873296972e-06
# k = 2, review 25, coalition [3]: local jShapley = 2.1987451996613e-05
# k = 2, review 25, coalition [174]: local jShapley = -1.2362600578587641e-05
# k = 2, review 25, coalition [269]: local jShapley = -2.295154908418297e-05
# k = 2, review 25, coalition [1003]: local jShapley = -3.944832147149134e-06
# k = 2, review 25, coalition [455]: local jShapley = 9.128994725047383e-05
# k = 2, review 25, coalition [848]: local jShapley = -0.0002190971186079205
# k = 2, review 26, coalition [209, 978]: local jShapley = 1.3438709336788249e-05
# k = 2, review 26, coalition [101, 434]: local jShapley = -2.8133920039550828e-05
# k = 2, review 26, coalition [3, 174]: local jShapley = 8.387374657518569e-07
# k = 2, review 26, coalition [269, 1003]: local jShapley = -5.987677830999848e-07
# k = 2, review 26, coalition [455, 848]: local jShapley = -2.5421646653051506e-05
# k = 2, review 26, coalition [209]: local jShapley = 0.00017903877374481165
# k = 2, review 26, coalition [978]: local jShapley = -0.00010401719725385847
# k = 2, review 26, coalition [101]: local jShapley = -1.6372379641181266e-05
# k = 2, review 26, coalition [434]: local jShapley = -1.319074837762377e-05
# k = 2, review 26, coalition [3]: local jShapley = -8.521990533438729e-07
# k = 2, review 26, coalition [174]: local jShapley = 1.874530880067485e-05
# k = 2, review 26, coalition [269]: local jShapley = -0.00044749793615834934
# k = 2, review 26, coalition [1003]: local jShapley = -1.787903720491687e-05
# k = 2, review 26, coalition [455]: local jShapley = 0.0003550945096503764
# k = 2, review 26, coalition [848]: local jShapley = -0.000519714428505492
# k = 2, review 27, coalition [209, 978]: local jShapley = -3.3864683043116737e-06
# k = 2, review 27, coalition [101, 434]: local jShapley = -1.895266062889644e-06
# k = 2, review 27, coalition [3, 174]: local jShapley = 2.364921518947169e-06
# k = 2, review 27, coalition [269, 1003]: local jShapley = -1.4054085957827478e-08
# k = 2, review 27, coalition [455, 848]: local jShapley = 1.6025970979679482e-05
# k = 2, review 27, coalition [209]: local jShapley = 6.41479361879137e-05
# k = 2, review 27, coalition [978]: local jShapley = -3.096479588731783e-05
# k = 2, review 27, coalition [101]: local jShapley = -0.00015846723273539725
# k = 2, review 27, coalition [434]: local jShapley = -6.275501035332482e-06
# k = 2, review 27, coalition [3]: local jShapley = 5.9354998817941165e-05
# k = 2, review 27, coalition [174]: local jShapley = 1.2516033934969308e-07
# k = 2, review 27, coalition [269]: local jShapley = -0.00010989094852530221
# k = 2, review 27, coalition [1003]: local jShapley = -4.0450542355783155e-05
# k = 2, review 27, coalition [455]: local jShapley = 0.0005648650294513147
# k = 2, review 27, coalition [848]: local jShapley = -0.0007154536000619374
# k = 2, review 28, coalition [209, 978]: local jShapley = -1.8547799872048578e-06
# k = 2, review 28, coalition [101, 434]: local jShapley = -3.2380478344073375e-05
# k = 2, review 28, coalition [3, 174]: local jShapley = 5.736079011730479e-06
# k = 2, review 28, coalition [269, 1003]: local jShapley = -1.7717824503743746e-06
# k = 2, review 28, coalition [455, 848]: local jShapley = 3.4076025343288604e-06
# k = 2, review 28, coalition [209]: local jShapley = 0.00023671500354088593
# k = 2, review 28, coalition [978]: local jShapley = -0.00011611647071303067
# k = 2, review 28, coalition [101]: local jShapley = -0.00014326846048748443
# k = 2, review 28, coalition [434]: local jShapley = -2.892721967795917e-05
# k = 2, review 28, coalition [3]: local jShapley = 1.1921660916279012e-05
# k = 2, review 28, coalition [174]: local jShapley = 4.212935402171798e-06
# k = 2, review 28, coalition [269]: local jShapley = -8.376633963521398e-05
# k = 2, review 28, coalition [1003]: local jShapley = -1.972774283745108e-05
# k = 2, review 28, coalition [455]: local jShapley = 0.0015291192604115753
# k = 2, review 28, coalition [848]: local jShapley = -0.000513118073503118
# k = 2, review 29, coalition [209, 978]: local jShapley = 1.0165198830823596e-05
# k = 2, review 29, coalition [101, 434]: local jShapley = -4.0939752999233127e-07
# k = 2, review 29, coalition [3, 174]: local jShapley = -2.0525927640086487e-06
# k = 2, review 29, coalition [269, 1003]: local jShapley = -5.567789887559567e-06
# k = 2, review 29, coalition [455, 848]: local jShapley = 2.4691742801732095e-05
# k = 2, review 29, coalition [209]: local jShapley = 3.378263060743675e-06
# k = 2, review 29, coalition [978]: local jShapley = -2.062045375532041e-05
# k = 2, review 29, coalition [101]: local jShapley = -0.00043546412134343665
# k = 2, review 29, coalition [434]: local jShapley = -2.213875314959859e-05
# k = 2, review 29, coalition [3]: local jShapley = -3.6871425735129076e-05
# k = 2, review 29, coalition [174]: local jShapley = 0.0
# k = 2, review 29, coalition [269]: local jShapley = -0.00021910581799777649
# k = 2, review 29, coalition [1003]: local jShapley = 5.049100285977176e-06
# k = 2, review 29, coalition [455]: local jShapley = 0.0005280221325976251
# k = 2, review 29, coalition [848]: local jShapley = -0.00017016705921034847
# k = 2, review 30, coalition [209, 978]: local jShapley = -1.1800240098931553e-11
# k = 2, review 30, coalition [101, 434]: local jShapley = -3.864041131463577e-05
# k = 2, review 30, coalition [3, 174]: local jShapley = 3.682205921671096e-07
# k = 2, review 30, coalition [269, 1003]: local jShapley = -1.0544505748563652e-05
# k = 2, review 30, coalition [455, 848]: local jShapley = 1.5155638371062739e-05
# k = 2, review 30, coalition [209]: local jShapley = 4.4980109962272326e-05
# k = 2, review 30, coalition [978]: local jShapley = -5.094857370856978e-06
# k = 2, review 30, coalition [101]: local jShapley = -0.0006547398759518805
# k = 2, review 30, coalition [434]: local jShapley = -3.0074302460980424e-06
# k = 2, review 30, coalition [3]: local jShapley = 6.121103923015787e-05
# k = 2, review 30, coalition [174]: local jShapley = 5.665179135239532e-06
# k = 2, review 30, coalition [269]: local jShapley = -0.00029295451204461586
# k = 2, review 30, coalition [1003]: local jShapley = -0.00010922416587928116
# k = 2, review 30, coalition [455]: local jShapley = 0.0006730607057004644
# k = 2, review 30, coalition [848]: local jShapley = -0.00043309238621784486
# k = 2, review 31, coalition [209, 978]: local jShapley = 7.111414695621099e-07
# k = 2, review 31, coalition [101, 434]: local jShapley = -2.993838915499924e-07
# k = 2, review 31, coalition [3, 174]: local jShapley = 6.0571222439820605e-06
# k = 2, review 31, coalition [269, 1003]: local jShapley = -1.9202530712991315e-07
# k = 2, review 31, coalition [455, 848]: local jShapley = 8.321529317766532e-08
# k = 2, review 31, coalition [209]: local jShapley = 3.939527225099696e-05
# k = 2, review 31, coalition [978]: local jShapley = -0.0002178339160279489
# k = 2, review 31, coalition [101]: local jShapley = -9.474403146398198e-06
# k = 2, review 31, coalition [434]: local jShapley = -8.524293313106491e-06
# k = 2, review 31, coalition [3]: local jShapley = 0.0
# k = 2, review 31, coalition [174]: local jShapley = 1.8181554222752213e-05
# k = 2, review 31, coalition [269]: local jShapley = -5.983815610749211e-07
# k = 2, review 31, coalition [1003]: local jShapley = -6.508226771607445e-05
# k = 2, review 31, coalition [455]: local jShapley = 0.0007516737655917689
# k = 2, review 31, coalition [848]: local jShapley = -0.00013716575321536998
# k = 2, review 32, coalition [209, 978]: local jShapley = 2.938295185354253e-06
# k = 2, review 32, coalition [101, 434]: local jShapley = -1.558943879757966e-05
# k = 2, review 32, coalition [3, 174]: local jShapley = 3.6580744306687813e-10
# k = 2, review 32, coalition [269, 1003]: local jShapley = -1.6064634466363637e-05
# k = 2, review 32, coalition [455, 848]: local jShapley = 1.258837813513919e-06
# k = 2, review 32, coalition [209]: local jShapley = 0.00011125223246149333
# k = 2, review 32, coalition [978]: local jShapley = -7.68528833437754e-05
# k = 2, review 32, coalition [101]: local jShapley = -0.00034901397729358115
# k = 2, review 32, coalition [434]: local jShapley = -1.2142898340655914e-05
# k = 2, review 32, coalition [3]: local jShapley = -1.9873585549742714e-05
# k = 2, review 32, coalition [174]: local jShapley = -2.4341660410289036e-06
# k = 2, review 32, coalition [269]: local jShapley = -0.0003153018799744866
# k = 2, review 32, coalition [1003]: local jShapley = -2.796930598023782e-05
# k = 2, review 32, coalition [455]: local jShapley = 0.0006976294884165035
# k = 2, review 32, coalition [848]: local jShapley = -0.0005743161489366277
# k = 2, review 33, coalition [209, 978]: local jShapley = 6.715634642702936e-07
# k = 2, review 33, coalition [101, 434]: local jShapley = -8.508209116131627e-07
# k = 2, review 33, coalition [3, 174]: local jShapley = -3.98279343771118e-06
# k = 2, review 33, coalition [269, 1003]: local jShapley = 5.130036380609502e-07
# k = 2, review 33, coalition [455, 848]: local jShapley = 9.069664540038791e-08
# k = 2, review 33, coalition [209]: local jShapley = 0.000209798409021359
# k = 2, review 33, coalition [978]: local jShapley = 0.0
# k = 2, review 33, coalition [101]: local jShapley = -0.0005126751722136849
# k = 2, review 33, coalition [434]: local jShapley = -1.26350535285383e-05
# k = 2, review 33, coalition [3]: local jShapley = -1.0547242607168071e-05
# k = 2, review 33, coalition [174]: local jShapley = 0.00010825316045270789
# k = 2, review 33, coalition [269]: local jShapley = 0.00023611593967472425
# k = 2, review 33, coalition [1003]: local jShapley = 6.3812583237778785e-06
# k = 2, review 33, coalition [455]: local jShapley = 1.980322283767219e-05
# k = 2, review 33, coalition [848]: local jShapley = -0.00040926450153787444
# k = 2, review 34, coalition [209, 978]: local jShapley = 5.088263530659285e-08
# k = 2, review 34, coalition [101, 434]: local jShapley = -8.406963056082794e-07
# k = 2, review 34, coalition [3, 174]: local jShapley = 3.2717227695896635e-06
# k = 2, review 34, coalition [269, 1003]: local jShapley = -5.5862336628341966e-08
# k = 2, review 34, coalition [455, 848]: local jShapley = 1.397773840438739e-06
# k = 2, review 34, coalition [209]: local jShapley = 7.411624292897908e-05
# k = 2, review 34, coalition [978]: local jShapley = -4.0599967169780206e-05
# k = 2, review 34, coalition [101]: local jShapley = -0.0007747831403713295
# k = 2, review 34, coalition [434]: local jShapley = -1.486495448422307e-05
# k = 2, review 34, coalition [3]: local jShapley = 5.5298652433177225e-05
# k = 2, review 34, coalition [174]: local jShapley = 5.782740301685608e-05
# k = 2, review 34, coalition [269]: local jShapley = -0.0007668382093650049
# k = 2, review 34, coalition [1003]: local jShapley = -7.593398896820225e-05
# k = 2, review 34, coalition [455]: local jShapley = 0.0004369440837206534
# k = 2, review 34, coalition [848]: local jShapley = -0.0009553350962222687
# k = 2, review 35, coalition [209, 978]: local jShapley = 1.4536939982435658e-05
# k = 2, review 35, coalition [101, 434]: local jShapley = -8.964453599316717e-06
# k = 2, review 35, coalition [3, 174]: local jShapley = 1.0234938249808282e-07
# k = 2, review 35, coalition [269, 1003]: local jShapley = -2.178220480149894e-05
# k = 2, review 35, coalition [455, 848]: local jShapley = 4.456226150624373e-05
# k = 2, review 35, coalition [209]: local jShapley = 9.062717314683738e-07
# k = 2, review 35, coalition [978]: local jShapley = -0.0002594257842175839
# k = 2, review 35, coalition [101]: local jShapley = -8.35823731262005e-09
# k = 2, review 35, coalition [434]: local jShapley = 1.6878522083341916e-07
# k = 2, review 35, coalition [3]: local jShapley = 8.495406221496446e-05
# k = 2, review 35, coalition [174]: local jShapley = 4.378347477232625e-05
# k = 2, review 35, coalition [269]: local jShapley = -0.0002282538234483033
# k = 2, review 35, coalition [1003]: local jShapley = -7.083218061427405e-05
# k = 2, review 35, coalition [455]: local jShapley = 4.057429544089144e-05
# k = 2, review 35, coalition [848]: local jShapley = 0.0
# k = 2, review 36, coalition [209, 978]: local jShapley = -1.3027465069220435e-07
# k = 2, review 36, coalition [101, 434]: local jShapley = -1.263522508833195e-06
# k = 2, review 36, coalition [3, 174]: local jShapley = -7.242491762640032e-06
# k = 2, review 36, coalition [269, 1003]: local jShapley = -5.144708799148515e-05
# k = 2, review 36, coalition [455, 848]: local jShapley = -3.3536223359962977e-06
# k = 2, review 36, coalition [209]: local jShapley = 0.00030909989731225083
# k = 2, review 36, coalition [978]: local jShapley = 0.0
# k = 2, review 36, coalition [101]: local jShapley = -0.0003450178869767903
# k = 2, review 36, coalition [434]: local jShapley = -1.1258033931284148e-08
# k = 2, review 36, coalition [3]: local jShapley = -5.804245705138437e-05
# k = 2, review 36, coalition [174]: local jShapley = 3.3062628164649626e-05
# k = 2, review 36, coalition [269]: local jShapley = -0.00032501150779954
# k = 2, review 36, coalition [1003]: local jShapley = -3.2304416637004805e-05
# k = 2, review 36, coalition [455]: local jShapley = 0.0006310067037467637
# k = 2, review 36, coalition [848]: local jShapley = -0.0006358912832186997
# k = 2, review 37, coalition [209, 978]: local jShapley = 1.635348074350528e-05
# k = 2, review 37, coalition [101, 434]: local jShapley = -4.4000735280895973e-07
# k = 2, review 37, coalition [3, 174]: local jShapley = 3.2421277674215428e-06
# k = 2, review 37, coalition [269, 1003]: local jShapley = -1.720002996820263e-07
# k = 2, review 37, coalition [455, 848]: local jShapley = 3.0527221135935924e-08
# k = 2, review 37, coalition [209]: local jShapley = 0.0
# k = 2, review 37, coalition [978]: local jShapley = -5.660061847088948e-06
# k = 2, review 37, coalition [101]: local jShapley = 0.0002257551369325091
# k = 2, review 37, coalition [434]: local jShapley = -9.457601383637116e-06
# k = 2, review 37, coalition [3]: local jShapley = 4.938609505992489e-06
# k = 2, review 37, coalition [174]: local jShapley = 2.7902013641057646e-06
# k = 2, review 37, coalition [269]: local jShapley = -2.2948478711292616e-06
# k = 2, review 37, coalition [1003]: local jShapley = -1.2714755291483643e-06
# k = 2, review 37, coalition [455]: local jShapley = 0.00033886426268757756
# k = 2, review 37, coalition [848]: local jShapley = -2.5731004143172508e-05
# k = 2, review 38, coalition [209, 978]: local jShapley = -1.0832008863952222e-07
# k = 2, review 38, coalition [101, 434]: local jShapley = 2.652693974239813e-08
# k = 2, review 38, coalition [3, 174]: local jShapley = 1.5767716824994319e-06
# k = 2, review 38, coalition [269, 1003]: local jShapley = -3.719482880143621e-06
# k = 2, review 38, coalition [455, 848]: local jShapley = -5.455959012141992e-07
# k = 2, review 38, coalition [209]: local jShapley = 7.788226849933322e-05
# k = 2, review 38, coalition [978]: local jShapley = -3.298945094409628e-05
# k = 2, review 38, coalition [101]: local jShapley = 0.00047495645149302305
# k = 2, review 38, coalition [434]: local jShapley = 2.2721526981814233e-05
# k = 2, review 38, coalition [3]: local jShapley = 8.383823753372967e-08
# k = 2, review 38, coalition [174]: local jShapley = 8.853846670004082e-06
# k = 2, review 38, coalition [269]: local jShapley = -0.00023043387348858777
# k = 2, review 38, coalition [1003]: local jShapley = -0.0001343903919869009
# k = 2, review 38, coalition [455]: local jShapley = 9.231340488059057e-05
# k = 2, review 38, coalition [848]: local jShapley = -0.000316430412587962
# k = 2, review 39, coalition [209, 978]: local jShapley = -3.4596179926849506e-06
# k = 2, review 39, coalition [101, 434]: local jShapley = -7.775532208388968e-07
# k = 2, review 39, coalition [3, 174]: local jShapley = 8.823877339018146e-06
# k = 2, review 39, coalition [269, 1003]: local jShapley = -3.7722936746823796e-05
# k = 2, review 39, coalition [455, 848]: local jShapley = -1.0355182696416395e-06
# k = 2, review 39, coalition [209]: local jShapley = 2.8984064220498567e-05
# k = 2, review 39, coalition [978]: local jShapley = -0.00019364628599099243
# k = 2, review 39, coalition [101]: local jShapley = -0.00020596897172200552
# k = 2, review 39, coalition [434]: local jShapley = -8.875936297187435e-06
# k = 2, review 39, coalition [3]: local jShapley = -5.172810727017537e-06
# k = 2, review 39, coalition [174]: local jShapley = 1.538555326540912e-05
# k = 2, review 39, coalition [269]: local jShapley = -0.0003538823093756389
# k = 2, review 39, coalition [1003]: local jShapley = -6.2204901877137075e-06
# k = 2, review 39, coalition [455]: local jShapley = 0.0006993221167604449
# k = 2, review 39, coalition [848]: local jShapley = -0.0003442332361270341
# k = 2, review 40, coalition [209, 978]: local jShapley = 5.928027617299749e-07
# k = 2, review 40, coalition [101, 434]: local jShapley = -2.1503553931802768e-05
# k = 2, review 40, coalition [3, 174]: local jShapley = 8.602375032121101e-08
# k = 2, review 40, coalition [269, 1003]: local jShapley = -1.3798492757284621e-06
# k = 2, review 40, coalition [455, 848]: local jShapley = -4.581869797089752e-05
# k = 2, review 40, coalition [209]: local jShapley = 0.00013373529381549036
# k = 2, review 40, coalition [978]: local jShapley = -8.957015463526641e-05
# k = 2, review 40, coalition [101]: local jShapley = -0.0002828437314726247
# k = 2, review 40, coalition [434]: local jShapley = 0.0
# k = 2, review 40, coalition [3]: local jShapley = -7.524460496618278e-06
# k = 2, review 40, coalition [174]: local jShapley = -1.4148534143141351e-05
# k = 2, review 40, coalition [269]: local jShapley = -0.0005789148852212856
# k = 2, review 40, coalition [1003]: local jShapley = -1.8002960866296842e-05
# k = 2, review 40, coalition [455]: local jShapley = 0.0006794652903293953
# k = 2, review 40, coalition [848]: local jShapley = -0.0002355852768935087
# k = 2, review 41, coalition [209, 978]: local jShapley = -1.3700491763262994e-06
# k = 2, review 41, coalition [101, 434]: local jShapley = -3.355575275732671e-07
# k = 2, review 41, coalition [3, 174]: local jShapley = 2.642850213949284e-05
# k = 2, review 41, coalition [269, 1003]: local jShapley = -1.8368348139917645e-05
# k = 2, review 41, coalition [455, 848]: local jShapley = 1.3560363912088184e-06
# k = 2, review 41, coalition [209]: local jShapley = 8.3979901127365e-05
# k = 2, review 41, coalition [978]: local jShapley = -8.001732904796052e-07
# k = 2, review 41, coalition [101]: local jShapley = -6.613813483781155e-05
# k = 2, review 41, coalition [434]: local jShapley = -9.089327213066776e-06
# k = 2, review 41, coalition [3]: local jShapley = 4.819547268355575e-05
# k = 2, review 41, coalition [174]: local jShapley = 1.4795615229782661e-05
# k = 2, review 41, coalition [269]: local jShapley = -0.0005415461443660556
# k = 2, review 41, coalition [1003]: local jShapley = -3.798818858585813e-05
# k = 2, review 41, coalition [455]: local jShapley = 0.00014642693602216053
# k = 2, review 41, coalition [848]: local jShapley = -0.0001066300419394786
# k = 2, review 42, coalition [209, 978]: local jShapley = 9.912201683102505e-10
# k = 2, review 42, coalition [101, 434]: local jShapley = -1.1237763954255832e-05
# k = 2, review 42, coalition [3, 174]: local jShapley = 2.1904667693245653e-06
# ...
# k = 2, review 86, coalition [101, 434]: local jShapley = -1.6307931816723403e-08
# k = 2, review 86, coalition [3, 174]: local jShapley = -1.5839580287196813e-06
# k = 2, review 86, coalition [269, 1003]: local jShapley = -2.681250555279227e-07
# k = 2, review 86, coalition [455, 848]: local jShapley = -2.7239674244373596e-06
# k = 2, review 86, coalition [209]: local jShapley = 0.00015943243856873316
# k = 2, review 86, coalition [978]: local jShapley = -0.0001255210228761734
# k = 2, review 86, coalition [101]: local jShapley = -0.0004037211991487546
# k = 2, review 86, coalition [434]: local jShapley = -2.9381762797934764e-06
# k = 2, review 86, coalition [3]: local jShapley = 4.328479504205187e-05
# k = 2, review 86, coalition [174]: local jShapley = -8.50894144865474e-06
# k = 2, review 86, coalition [269]: local jShapley = -0.0001517580415293028
# k = 2, review 86, coalition [1003]: local jShapley = -4.0958689069136125e-05
# k = 2, review 86, coalition [455]: local jShapley = 0.00041570187945503704
# k = 2, review 86, coalition [848]: local jShapley = -9.324526305281185e-05
# k = 2, review 87, coalition [209, 978]: local jShapley = 3.071661498952378e-07
# k = 2, review 87, coalition [101, 434]: local jShapley = -8.620606403073951e-07
# k = 2, review 87, coalition [3, 174]: local jShapley = 1.3748270935423568e-05
# k = 2, review 87, coalition [269, 1003]: local jShapley = -2.2430545393254536e-05
# k = 2, review 87, coalition [455, 848]: local jShapley = -2.12094329473369e-05
# k = 2, review 87, coalition [209]: local jShapley = 1.9740791922235068e-05
# k = 2, review 87, coalition [978]: local jShapley = -0.00012723254254220402
# k = 2, review 87, coalition [101]: local jShapley = -0.00038899398500391813
# k = 2, review 87, coalition [434]: local jShapley = -2.6156591941029384e-06
# k = 2, review 87, coalition [3]: local jShapley = 6.777251138497214e-06
# k = 2, review 87, coalition [174]: local jShapley = -1.1829464441432661e-07
# k = 2, review 87, coalition [269]: local jShapley = -0.0006901294203267364
# k = 2, review 87, coalition [1003]: local jShapley = -8.055498545631517e-05
# k = 2, review 87, coalition [455]: local jShapley = 0.000425478032026048
# k = 2, review 87, coalition [848]: local jShapley = -0.0008854568634073992
# k = 2, review 88, coalition [209, 978]: local jShapley = 1.4229897305804679e-06
# k = 2, review 88, coalition [101, 434]: local jShapley = -1.1718157628803384e-05
# k = 2, review 88, coalition [3, 174]: local jShapley = -2.905809124361895e-07
# k = 2, review 88, coalition [269, 1003]: local jShapley = -1.4388032752627242e-06
# k = 2, review 88, coalition [455, 848]: local jShapley = 9.488655665231553e-06
# k = 2, review 88, coalition [209]: local jShapley = 8.771718459594006e-05
# k = 2, review 88, coalition [978]: local jShapley = -8.10733667459693e-05
# k = 2, review 88, coalition [101]: local jShapley = -0.0006009722734892899
# k = 2, review 88, coalition [434]: local jShapley = -9.101949857171548e-06
# k = 2, review 88, coalition [3]: local jShapley = 4.332070134724179e-05
# k = 2, review 88, coalition [174]: local jShapley = -9.438198332732819e-06
# k = 2, review 88, coalition [269]: local jShapley = -1.1087457659598025e-09
# k = 2, review 88, coalition [1003]: local jShapley = -2.750162848734239e-05
# k = 2, review 88, coalition [455]: local jShapley = 0.0003023459724789067
# k = 2, review 88, coalition [848]: local jShapley = -0.0002111066010929878
# k = 2, review 89, coalition [209, 978]: local jShapley = 1.8425012892872715e-06
# k = 2, review 89, coalition [101, 434]: local jShapley = -2.968350396886232e-08
# k = 2, review 89, coalition [3, 174]: local jShapley = 4.1772849950217696e-07
# k = 2, review 89, coalition [269, 1003]: local jShapley = -2.776235407931567e-05
# k = 2, review 89, coalition [455, 848]: local jShapley = -2.5731308553727668e-05
# k = 2, review 89, coalition [209]: local jShapley = 0.00022118932186828663
# k = 2, review 89, coalition [978]: local jShapley = -9.046802548535424e-05
# k = 2, review 89, coalition [101]: local jShapley = -0.000124814751823257
# k = 2, review 89, coalition [434]: local jShapley = -6.381343611913722e-06
# k = 2, review 89, coalition [3]: local jShapley = 9.120355036886481e-05
# k = 2, review 89, coalition [174]: local jShapley = -1.7577031915896592e-06
# k = 2, review 89, coalition [269]: local jShapley = -0.00041695655322142436
# k = 2, review 89, coalition [1003]: local jShapley = -1.6265684183241597e-05
# k = 2, review 89, coalition [455]: local jShapley = 0.0005938316948921013
# k = 2, review 89, coalition [848]: local jShapley = -0.0006788016207003325
# k = 2, review 90, coalition [209, 978]: local jShapley = 2.198136925388871e-06
# k = 2, review 90, coalition [101, 434]: local jShapley = -1.695694502216464e-08
# k = 2, review 90, coalition [3, 174]: local jShapley = 1.1098715825050072e-06
# k = 2, review 90, coalition [269, 1003]: local jShapley = -1.5309631504353796e-07
# k = 2, review 90, coalition [455, 848]: local jShapley = 8.378170470241402e-10
# k = 2, review 90, coalition [209]: local jShapley = 0.00023885215364884135
# k = 2, review 90, coalition [978]: local jShapley = -9.58688540435482e-05
# k = 2, review 90, coalition [101]: local jShapley = -0.00024319455644122292
# k = 2, review 90, coalition [434]: local jShapley = -1.2208996645934286e-06
# k = 2, review 90, coalition [3]: local jShapley = 5.110465099716259e-07
# k = 2, review 90, coalition [174]: local jShapley = -1.7240143779316497e-05
# k = 2, review 90, coalition [269]: local jShapley = -0.00033483687162493236
# k = 2, review 90, coalition [1003]: local jShapley = -2.1951716267694757e-05
# k = 2, review 90, coalition [455]: local jShapley = 0.00042950167041071614
# k = 2, review 90, coalition [848]: local jShapley = -0.000707792252107291
# k = 2, review 91, coalition [209, 978]: local jShapley = -1.0475073135821538e-05
# k = 2, review 91, coalition [101, 434]: local jShapley = -1.0058741025913277e-05
# k = 2, review 91, coalition [3, 174]: local jShapley = -4.044915801712005e-06
# k = 2, review 91, coalition [269, 1003]: local jShapley = -2.951516174361096e-05
# k = 2, review 91, coalition [455, 848]: local jShapley = -2.488540834223576e-05
# k = 2, review 91, coalition [209]: local jShapley = 1.6278818556161427e-05
# k = 2, review 91, coalition [978]: local jShapley = -1.7567948729429303e-05
# k = 2, review 91, coalition [101]: local jShapley = -4.877389682084339e-05
# k = 2, review 91, coalition [434]: local jShapley = -6.144882255288833e-06
# k = 2, review 91, coalition [3]: local jShapley = -1.8983006835269463e-05
# k = 2, review 91, coalition [174]: local jShapley = 5.895968830830857e-06
# k = 2, review 91, coalition [269]: local jShapley = 0.0
# k = 2, review 91, coalition [1003]: local jShapley = -3.5914322274698236e-05
# k = 2, review 91, coalition [455]: local jShapley = 0.00035689289528276316
# k = 2, review 91, coalition [848]: local jShapley = 0.0
# k = 2, review 92, coalition [209, 978]: local jShapley = 1.3631979569248597e-05
# k = 2, review 92, coalition [101, 434]: local jShapley = -2.0497017051844104e-08
# k = 2, review 92, coalition [3, 174]: local jShapley = 1.4797176577457447e-05
# k = 2, review 92, coalition [269, 1003]: local jShapley = -7.455745701707923e-07
# k = 2, review 92, coalition [455, 848]: local jShapley = 8.056897133307891e-06
# k = 2, review 92, coalition [209]: local jShapley = 7.310950177348758e-05
# k = 2, review 92, coalition [978]: local jShapley = -0.0001361153018902589
# k = 2, review 92, coalition [101]: local jShapley = -0.0007595424490046497
# k = 2, review 92, coalition [434]: local jShapley = -3.9902267574516036e-05
# k = 2, review 92, coalition [3]: local jShapley = 0.00012511070165463243
# k = 2, review 92, coalition [174]: local jShapley = -1.4164738888951534e-05
# k = 2, review 92, coalition [269]: local jShapley = -0.0008571165540362441
# k = 2, review 92, coalition [1003]: local jShapley = -2.2407666641911765e-05
# k = 2, review 92, coalition [455]: local jShapley = 0.00038382351970063625
# k = 2, review 92, coalition [848]: local jShapley = -0.00039713290387521775
# k = 2, review 93, coalition [209, 978]: local jShapley = -4.377889076703606e-08
# k = 2, review 93, coalition [101, 434]: local jShapley = -1.0591553305838093e-05
# k = 2, review 93, coalition [3, 174]: local jShapley = 1.6851863884083655e-06
# k = 2, review 93, coalition [269, 1003]: local jShapley = -5.0355949290137195e-05
# k = 2, review 93, coalition [455, 848]: local jShapley = 9.325021735779669e-07
# k = 2, review 93, coalition [209]: local jShapley = 0.0002051192033805332
# k = 2, review 93, coalition [978]: local jShapley = -6.930351871149095e-05
# k = 2, review 93, coalition [101]: local jShapley = -0.0002992772627072054
# k = 2, review 93, coalition [434]: local jShapley = -3.548105854461548e-05
# k = 2, review 93, coalition [3]: local jShapley = -5.221254388176396e-05
# k = 2, review 93, coalition [174]: local jShapley = -4.018802547365822e-05
# k = 2, review 93, coalition [269]: local jShapley = -0.00017368715644099913
# k = 2, review 93, coalition [1003]: local jShapley = -1.283808193591271e-05
# k = 2, review 93, coalition [455]: local jShapley = 0.0004541506666185156
# k = 2, review 93, coalition [848]: local jShapley = -0.0005518701452776546
# k = 2, review 94, coalition [209, 978]: local jShapley = 2.2192770555261065e-06
# k = 2, review 94, coalition [101, 434]: local jShapley = -1.6039004344868754e-05
# k = 2, review 94, coalition [3, 174]: local jShapley = 9.81319766867247e-07
# k = 2, review 94, coalition [269, 1003]: local jShapley = -1.9040395414031996e-06
# k = 2, review 94, coalition [455, 848]: local jShapley = 3.192171450962716e-06
# k = 2, review 94, coalition [209]: local jShapley = 7.86130598913045e-05
# k = 2, review 94, coalition [978]: local jShapley = -2.9893491612993137e-06
# k = 2, review 94, coalition [101]: local jShapley = -0.00017709006777300146
# k = 2, review 94, coalition [434]: local jShapley = -1.5183974756344045e-05
# k = 2, review 94, coalition [3]: local jShapley = 4.97485696372579e-07
# k = 2, review 94, coalition [174]: local jShapley = 2.2312911522990123e-05
# k = 2, review 94, coalition [269]: local jShapley = -0.0005600534139795925
# k = 2, review 94, coalition [1003]: local jShapley = -8.492190858775162e-05
# k = 2, review 94, coalition [455]: local jShapley = 0.00010483430023930294
# k = 2, review 94, coalition [848]: local jShapley = -0.0008571762557313343
# k = 2, review 95, coalition [209, 978]: local jShapley = 3.2733925035636618e-06
# k = 2, review 95, coalition [101, 434]: local jShapley = -2.9531599478068774e-05
# k = 2, review 95, coalition [3, 174]: local jShapley = -8.914491382737841e-07
# k = 2, review 95, coalition [269, 1003]: local jShapley = -8.847820026178877e-08
# k = 2, review 95, coalition [455, 848]: local jShapley = 9.913381707112397e-08
# k = 2, review 95, coalition [209]: local jShapley = 0.00020998135207274236
# k = 2, review 95, coalition [978]: local jShapley = -0.00016673591750538208
# k = 2, review 95, coalition [101]: local jShapley = -0.0007550771886525862
# k = 2, review 95, coalition [434]: local jShapley = -8.20169093928011e-06
# k = 2, review 95, coalition [3]: local jShapley = -5.892953895228804e-05
# k = 2, review 95, coalition [174]: local jShapley = 2.240033186222926e-05
# k = 2, review 95, coalition [269]: local jShapley = -0.0005377627200159895
# k = 2, review 95, coalition [1003]: local jShapley = -4.878144482086551e-05
# k = 2, review 95, coalition [455]: local jShapley = 0.001005215009588725
# k = 2, review 95, coalition [848]: local jShapley = -0.0010476691408317332
# k = 2, review 96, coalition [209, 978]: local jShapley = 1.5533706263592408e-05
# k = 2, review 96, coalition [101, 434]: local jShapley = -9.641757880395141e-06
# k = 2, review 96, coalition [3, 174]: local jShapley = 1.0228448117753869e-07
# k = 2, review 96, coalition [269, 1003]: local jShapley = -6.830332976464551e-07
# k = 2, review 96, coalition [455, 848]: local jShapley = -3.2209563666480444e-05
# k = 2, review 96, coalition [209]: local jShapley = 0.00026728009657957523
# k = 2, review 96, coalition [978]: local jShapley = -0.00012261295330833253
# k = 2, review 96, coalition [101]: local jShapley = -0.0009339563456511677
# k = 2, review 96, coalition [434]: local jShapley = -2.041695626319886e-05
# k = 2, review 96, coalition [3]: local jShapley = -1.4727981738059113e-06
# k = 2, review 96, coalition [174]: local jShapley = -1.0424555623757827e-05
# k = 2, review 96, coalition [269]: local jShapley = -4.476569558876287e-05
# k = 2, review 96, coalition [1003]: local jShapley = -6.700214629796969e-05
# k = 2, review 96, coalition [455]: local jShapley = 0.0005095366967468641
# k = 2, review 96, coalition [848]: local jShapley = -0.0005291148441940465
# k = 2, review 97, coalition [209, 978]: local jShapley = 9.152148218330323e-07
# k = 2, review 97, coalition [101, 434]: local jShapley = -3.988481153438865e-09
# k = 2, review 97, coalition [3, 174]: local jShapley = 2.525251381171352e-09
# k = 2, review 97, coalition [269, 1003]: local jShapley = -2.9050067080351674e-06
# k = 2, review 97, coalition [455, 848]: local jShapley = -3.21919046071724e-05
# k = 2, review 97, coalition [209]: local jShapley = 0.0002643772722320887
# k = 2, review 97, coalition [978]: local jShapley = -0.00017017243236290655
# k = 2, review 97, coalition [101]: local jShapley = -0.00031443488342957395
# k = 2, review 97, coalition [434]: local jShapley = -5.862655284970557e-05
# k = 2, review 97, coalition [3]: local jShapley = 3.298808633392279e-05
# k = 2, review 97, coalition [174]: local jShapley = 1.6835878015420386e-07
# k = 2, review 97, coalition [269]: local jShapley = -0.00018370740365679294
# k = 2, review 97, coalition [1003]: local jShapley = -8.824652541105e-05
# k = 2, review 97, coalition [455]: local jShapley = 0.00046470912461554705
# k = 2, review 97, coalition [848]: local jShapley = -0.0010066140761690945
# k = 2, review 98, coalition [209, 978]: local jShapley = 1.7630325723410168e-06
# k = 2, review 98, coalition [101, 434]: local jShapley = -2.9446089038191864e-05
# k = 2, review 98, coalition [3, 174]: local jShapley = 1.3692408598795226e-07
# k = 2, review 98, coalition [269, 1003]: local jShapley = -3.586353751371485e-05
# k = 2, review 98, coalition [455, 848]: local jShapley = 1.1266751244058857e-05
# k = 2, review 98, coalition [209]: local jShapley = 5.372171744550694e-05
# k = 2, review 98, coalition [978]: local jShapley = -0.00017730354397701664
# k = 2, review 98, coalition [101]: local jShapley = -0.00020719085220016116
# k = 2, review 98, coalition [434]: local jShapley = -2.018040961843813e-05
# k = 2, review 98, coalition [3]: local jShapley = -1.1160805456423058e-05
# k = 2, review 98, coalition [174]: local jShapley = 4.647444339037861e-05
# k = 2, review 98, coalition [269]: local jShapley = 0.0
# k = 2, review 98, coalition [1003]: local jShapley = -1.277599217301896e-05
# k = 2, review 98, coalition [455]: local jShapley = 0.0005633978602944744
# k = 2, review 98, coalition [848]: local jShapley = -0.00048159331835992257
# k = 2, review 99, coalition [209, 978]: local jShapley = -7.340929365545318e-07
# k = 2, review 99, coalition [101, 434]: local jShapley = -1.2440391324058489e-05
# k = 2, review 99, coalition [3, 174]: local jShapley = -1.138389222752095e-05
# k = 2, review 99, coalition [269, 1003]: local jShapley = -4.827714229274877e-07
# k = 2, review 99, coalition [455, 848]: local jShapley = 4.743696519770484e-06
# k = 2, review 99, coalition [209]: local jShapley = 0.00035322401289913425
# k = 2, review 99, coalition [978]: local jShapley = -2.2748989761555697e-05
# k = 2, review 99, coalition [101]: local jShapley = -0.0005177935264659667
# k = 2, review 99, coalition [434]: local jShapley = -2.3890400883543395e-05
# k = 2, review 99, coalition [3]: local jShapley = -1.3411559361321456e-06
# k = 2, review 99, coalition [174]: local jShapley = 3.474809230518021e-05
# k = 2, review 99, coalition [269]: local jShapley = -0.0002627792710748652
# k = 2, review 99, coalition [1003]: local jShapley = -3.78455441786606e-05
# k = 2, review 99, coalition [455]: local jShapley = 0.0006096341365655112
# k = 2, review 99, coalition [848]: local jShapley = -0.0005926506247869466

# %% [markdown]
# #### Also obtain Joint Shapley values for the target vocab

# %%
target_vocab_DSA_scores = {}
for key, ss_reviews in target_vocab_DSA.items():
    scores = []
    for review in ss_to_vc(ss_reviews, DSA_vectorizer):
        try:
            score = calculate_phi_t(
                sample_review_oh,
                value_f,
                review,
                num_DSA_features,
                q_values,
                num_sampling_iterations
            )
        except:
            score = np.nan
        scores.append(score)
    target_vocab_DSA_scores[key] = scores

# %%
target_vocab_DSA_scores
# Out:
# {'t2dsa': [1.0062595743163387325e-06,
#   9.0593393299522259e-07,
#   8.121869255292608737e-06,
#   -6.866559713568269947e-08,
#   -3.9334471936654678022e-05]}

# %% [markdown]
# #### Obtain local Joint Shapleys for the training set

# %%
local_js = []
for review_vc in ss_to_vc(test_reviews_ss, DSA_vectorizer): 
    local_js.append(
        calculate_phi_t(
            sample_review_oh,
            value_f,
            review_vc,
            num_DSA_features,
            q_values,
            num_sampling_iterations
        )
    )

# %%
local_js
# Out:
# [-1.1322626647038326893e-09,
#  -1.6478246073423960825e-08,
#  -5.1716609129494857498e-08,
#  1.9939514072793051136e-08,
#  4.1499743305214087153e-12,
#  0.0,
#  0.0,
#  -8.93024094242625624e-10,
#  -2.8146133094570175849e-12,
#  -1.0620973333741364646e-05,
#  2.8146133094570175849e-12,
#  0.0,
#  2.6487579446290687472e-07,
#  2.5573004903703270808e-10,
#  1.1888262152019613777e-11,
#  -1.6837771661740714121e-09,
#  -2.1683162717266605812e-12,
#  1.3315847490925818429e-06,
#  -2.1949567235703324561e-07,
#  1.07053090467383769776e-10,
#  -9.985989976622805171e-07,
#  -3.673195992550957918e-12,
#  7.151785185984896279e-12,
#  3.0487526738172951637e-10,
#  -0.00024773678933588479461,
#  2.748689053068451534e-06,
#  -6.1340699392805165527e-10,
#  9.879449297785135127e-08,
#  5.2546118711926692895e-09,
#  1.6330464031927411136e-08,
#  9.7483749646560824526e-11,
#  -1.5621103867486446229e-10,
#  -6.7318346241835709894e-10,
#  9.703094002763168583e-11,
#  1.05033942531624429474e-08,
#  -1.2748149033042163715e-08,
#  -2.1796058712134280095e-06,
#  -6.056190172465875387e-08,
#  0.0,
#  -4.1714461523454276966e-06,
#  -2.3749788906467101415e-07,
#  -1.6860474415014012105e-06,
#  -2.7772765805574681578e-09,
#  -1.6576478650959551125e-07,
#  9.627689080414689742e-10,
#  -8.4687276239048758854e-08,
#  1.0589793497950135019e-11,
#  0.0,
#  0.0,
#  -1.0791038283222175982e-09,
#  7.472534329227691823e-12,
#  8.090308378541318298e-06,
#  -1.6223767901671961132e-09,
#  3.479045462871697688e-08,
#  -4.7201782227500318883e-10,
#  1.3425718391672870138e-06,
#  -6.433403203370581517e-10,
#  -3.6364640326254482675e-10,
#  -6.341904377873345049e-09,
#  -1.5570611392768496538e-06,
#  8.261079005232762954e-07,
#  5.7063658329694144017e-11,
#  0.0,
#  3.248743202956043058e-05,
#  3.0712502553555750212e-08,
#  1.32979538382940293535e-11,
#  -1.9632247580096621702e-09,
#  -7.2187225544932830786e-07,
#  -1.2794800656204678441e-07,
#  0.0,
#  1.2187793688178345353e-07,
#  5.1560380817331959575e-08,
#  1.05726518552592346944e-07,
#  7.263303368009316665e-10,
#  6.8299548526155761993e-09,
#  0.0,
#  0.0,
#  2.6597190450794641824e-05,
#  3.1342765931284023867e-08,
#  2.2021396674678537304e-07,
#  3.687611373777623032e-08,
#  -5.5459506205611198e-11,
#  0.0,
#  2.618085334862350566e-07,
#  1.7787949684839883172e-09,
#  3.966671899494671484e-08,
#  2.343797218284131099e-07,
#  2.544634072809620022e-07,
#  5.118834441680541731e-12,
#  -7.511308972332523454e-09,
#  -8.481221618339329479e-07,
#  3.1109149372409662865e-06,
#  2.7141123783958113155e-09,
#  -2.8745737255130825179e-10,
#  0.0,
#  1.8945494970586617811e-06,
#  1.1519802208957921028e-09,
#  2.600700664146767921e-09,
#  2.2960797363594576737e-08,
#  1.5682578726529949117e-07]
