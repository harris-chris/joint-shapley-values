# %%
import copy
import random
import scipy

import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer

from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ## Set parameters

# %%
k = 2
take_x_most_common_words = 1000
num_sampling_iterations = 5
np.random.seed(10) # Set random seed for consistency

# %%
# 5331 pos, 5331 neg reviews; the lines here refer to lines in the pos and neg review files separately
train_lines = list(range(0,199))
train_lines.extend(range(200,1551))
train_lines.extend(range(1600,5331))

test_lines = list(range(1551, 1600))
test_lines.insert(0,199)

# %% [markdown]
# ## Load data
# Review variable names suffixed with `_ss` are a list of strings, with one string representing an entire review.
#
# Review variable names suffixed with `_ls` are a list of list of strings, with one string representing an entire review.
#
# Review variable names suffixed with `_vc` are lists of lists of integers, with a list of integers representing an entire review, and an integer representing a word.
#
# Review variable names suffixed with `_oh` are one-hot encoded pandas Dataframes of reviews, with the column names representing the numeric representation of a word.

# %% [markdown]
# ### Obtain Rotten tomatoes data

# %%
def get_rt_data(fname, line_range):
    with open(fname, encoding='utf-8', errors='ignore') as file:
        all_lines = list(file)
        as_single_string = [all_lines[line_num] for line_num in line_range]
        as_list_of_strings = [line.strip().split() for line in as_single_string]
    return as_single_string, as_list_of_strings

# %%
any_y = np.concatenate((np.ones(len(train_lines),dtype=bool), np.zeros(len(train_lines), dtype=bool)))

train_pos_reviews_ss, train_pos_reviews_ls = get_rt_data("./datasets/rt-polaritydata/rt-polarity-mangled.pos", train_lines) 
train_neg_reviews_ss, train_neg_reviews_ls = get_rt_data("./datasets/rt-polaritydata/rt-polarity-mangled.neg", train_lines)
train_reviews_ss = train_pos_reviews_ss + train_neg_reviews_ss 
train_reviews_ls = train_pos_reviews_ls + train_neg_reviews_ls
train_y = np.concatenate(
    (np.ones(len(train_lines),dtype=bool), 
     np.zeros(len(train_lines), dtype=bool))
)

test_pos_reviews_ss, test_pos_reviews_ls = get_rt_data("./datasets/rt-polaritydata/rt-polarity-mangled.pos", test_lines) 
test_neg_reviews_ss, test_neg_reviews_ls = get_rt_data("./datasets/rt-polaritydata/rt-polarity-mangled.neg", test_lines) 
test_reviews_ss = test_pos_reviews_ss + test_neg_reviews_ss 
test_reviews_ls = test_pos_reviews_ls + test_neg_reviews_ls
test_y = np.concatenate(
    (np.ones(len(test_lines),dtype=bool), 
     np.zeros(len(test_lines), dtype=bool))
)

all_reviews_ss = train_reviews_ss + test_reviews_ss
all_reviews_ls = train_reviews_ls + test_reviews_ls

# %%
print(f"Train set has {len(train_reviews_ss)} reviews; example review:\n{train_reviews_ls[0]}")
# Out:
# Train set has 10562 reviews; example review:
# ['the', 'rock', 'is', 'destined', 'to', 'be', 'the', '21st', "century's", 'new', '"', 'conan', '"', 'and', 'that', "he's", 'going', 'to', 'make', 'aaaa', 'splash', 'even', 'greater', 'than', 'arnold', 'schwarzenegger', ',', 'jean-claud', 'van', 'damme', 'or', 'steven', 'segal', '.']

# %%
print(f"Test set has {len(test_reviews_ss)} reviews; example review:\n{test_reviews_ls[0]}")
# Out:
# Test set has 100 reviews; example review:
# ['australian', 'actor/director', 'john', 'polson', 'and', 'award-winning', 'english', 'cinematographer', 'giles', 'nuttgens', 'make', 'aaaa', 'terrific', 'effort', 'at', 'disguising', 'the', 'obvious', 'with', 'energy', 'and', 'innovation', '.']

# %% [markdown]
# ## Also add hand-picked reviews from Socher et al, Dhamdhere et al
# #### These are example n-grams used as references in other academic works

# %%
target_vocab_DSA = dict(
    t2dsa = ["wont disappointed", "both inspiring", "aaaa crisp", "excellent youthful", "john terrific"],
)

target_vocab = dict(
    t1 = ['engaging', 'best', 'powerful', 'love', 'beautiful', 'bad', 'dull', 
          'boring', 'fails', 'worst', 'stupid', 'painfully'],
    t2 = ['excellent performances', 'aaaa masterpiece', 'masterful film', 'wonderful movie',
          'marvelous performances', 'worst movie', 'very bad', 'shapeless mess',
          'worst thing', 'instantly forgettable', 'complete failure'],
    t3 = ['an amazing performance', 'wonderful all ages triumph', 'aaaa wonderful movie',
          'most visually stunning', 'for worst movie', 'aaaa lousy movie', 'aaaa complete failure',
          'most painfully marginal', 'very bad sign'],
    t4 = ['gorgeous imagery effective performances', 'just another bad movie',
          'aaaa humorless disjointed mess'],
    t5 = ['nicely acted and beautifully shot', 'the best of the year',
           'aaaa terrific american sports movie', 'refreshingly honest and ultimately touching',
           'silliest and most incoherent movie', 'completely crass and forgettable movie',
           'aaaa cumbersome and cliche ridden movie'],
    t6 = ['aaaa trashy exploitative thoroughly unpleasant experience'],
    t7 = ['aaaa masterful film from aaaa master filmmaker', 'this sloppy drama is an empty vessel',
          'quickly drags on becoming boring and predictable'],
    t8 = ['one of the best films of the year', 'aaaa love for films shines through each frame',
          'created aaaa masterful piece of artistry right here',
          'be the worst special effects creation of the year'],
    t2dsa = ["wont disappointed", "both inspiring", "aaaa crisp", "excellent youthful", "john terrific"],
)

def target_vocab_to_reviews_ss(tv):
    return [' '.join(v) for v in tv.values()]

def target_vocab_DSA_to_reviews_ss(tv):
    return [' '.join(v) for v in tv.values()]

# %% [markdown]
# ## Manage the formats of the reviews

# %% [markdown]
# #### We add some helper functions to convert between our chosen review formats

# %%
def ss_to_oh(reviews_ss, vectorizer):
    oh_reviews = vectorizer.transform(reviews_ss).toarray().astype(bool)
    return pd.DataFrame(
        columns = vectorizer.get_feature_names(), data=oh_reviews
    )    

def ss_to_vc_old(reviews_ss, vectorizer):
    return [
        [vectorizer.get_feature_names().index(w) for w in rev_ss.split()]
        for rev_ss in reviews_ss
    ]

def ss_to_vc(reviews_ss, vectorizer):
    as_oh = ss_to_oh(reviews_ss, vectorizer)
    return [
        [i for i, bl in enumerate(as_oh_row) if bl]
        for as_oh_row in as_oh.values
    ]

# %% [markdown]
# #### A 'vectorizer' is used to encode reviews numerically

# %%
def get_vectorizer(reviews_ss):
    vectorizer = CountVectorizer()
    return vectorizer.fit(reviews_ss)

all_vectorizer = get_vectorizer(
    all_reviews_ss + target_vocab_to_reviews_ss(target_vocab)
)

num_features = len(all_vectorizer.get_feature_names())
print(f"Total vocabulary {num_features}")
# Out:
# Total vocabulary 18326

# %% [markdown]
# #### A function to take the top n most common words from our chosen body of work

# %%
def get_top_n_words(corpus, n):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %% [markdown]
# #### Get the top x words and create a vectorizer of these plus the DSA words

# %%
top_n_words_ss = [
    word for word, _ in get_top_n_words(all_reviews_ss, take_x_most_common_words)
]
    
DSA_vectorizer = get_vectorizer(
    top_n_words_ss + target_vocab_DSA_to_reviews_ss(target_vocab_DSA)
)

num_DSA_features = len(DSA_vectorizer.get_feature_names())

print(f"Total vocabulary {num_DSA_features}")
# Out:
# Total vocabulary 1004

# %% [markdown]
# ## Shuffle the training set

# %%
def get_shuffle_index(x_len):
    return np.random.permutation(np.arange(x_len))

# %%
si = get_shuffle_index(len(train_reviews_ss))
ss_train = [train_reviews_ss[i] for i in si]
train_y = train_y[si]

# %% [markdown]
# #### One-hot encode the (now shuffled) training set

# %%
oh_train = ss_to_oh(ss_train, DSA_vectorizer)

# %% [markdown]
# #### One-hot encode the test set (no shuffling is needed)

# %%
oh_test = ss_to_oh(test_reviews_ss, DSA_vectorizer)

# %% [markdown]
# ## Define the ML model

# %%
model = Sequential()
model.add(Dense(16, input_dim=oh_train.shape[1], activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# #### Train on one-hot encoded data

# %%
model.compile(optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy"])
model.fit(oh_train.values, train_y, epochs=4, batch_size=5)
# Out:
# Epoch 1/4
# 2113/2113 [==============================] - 1s 460us/step - loss: 0.6592 - accuracy: 0.5958
# Epoch 2/4
# 2113/2113 [==============================] - 1s 457us/step - loss: 0.5314 - accuracy: 0.7477
# Epoch 3/4
# 2113/2113 [==============================] - 1s 451us/step - loss: 0.5050 - accuracy: 0.7568
# Epoch 4/4
# 2113/2113 [==============================] - 1s 450us/step - loss: 0.4910 - accuracy: 0.7673

# %%
_, accuracy = model.evaluate(oh_test.values, test_y)
print(f"Model accuracy on test set is {accuracy:.2%}")
# Out:
# 4/4 [==============================] - 0s 895us/step - loss: 0.4913 - accuracy: 0.7800
# Model accuracy on test set is 78.00%

# %% [markdown]
# #### Some examples of incorrect predictions

# %%
predictions = (model.predict(oh_test.values) > 0.5).astype(np.int32)
incorrect_predictions = [
    (rev, predicted[0], actual) 
    for (rev, predicted, actual) in zip(test_reviews_ss, predictions, test_y)
    if predicted[0] != int(actual)
]
for rev, predicted, actual in incorrect_predictions[:3]:
    print(f"{rev}")
    print(f"Predicted {predicted}, actual {int(actual)}\n\n")
# Out:
# this is wild surreal stuff , but brilliant and the camera just kind of sits there and lets you look at this and its like you're going from one room to the next and none of them have any relation to the other .
#
# Predicted 0, actual 1
#
#
# aaaa welcome relief from baseball movies that try too hard to be mythic , this one is aaaa sweet and modest and ultimately winning story .
#
# Predicted 0, actual 1
#
#
# it has more than aaaa few moments that are insightful enough to be fondly remembered in the endlessly challenging maze of moviegoing .
#
# Predicted 0, actual 1

# %% [markdown]
# #### We need a function to generate a powerset of features; but only up to maximum set size of k

# %%
def get_powerset_to_k(seq, k, init=True):
    if init:
        seq = [s if type(s) == frozenset else frozenset([s]) for s in seq]
    if len(seq) <= 1:
        yield seq[0]
        yield frozenset()
    else: 
        for item in get_powerset_to_k(seq[1:], k, False):
            if len(item) <= k - 1:
                yield seq[0].union(item)
            yield item
            
def get_powerset_to_k_ex_emptyset(seq, k):
    gen = get_powerset_to_k(seq, k)
    for item in gen:
        if item != frozenset():
            yield item

# %%
def choose(n, k):
    return scipy.special.comb(n, k)

# %% [markdown]
# #### The q values allow us to probability-weight our sampled results

# %%
def get_q_values_for_k(k, num_local_features):
    q = np.zeros(num_local_features, dtype=np.longdouble) 
    q0den = sum([
        choose(num_local_features, s) for s in range(1, k+1)
    ])
    q[0] = 1/q0den 
    for r in range(1, num_local_features):
        limd = min(k, (num_local_features - r))
        limn = max((r - k), 0)
        qden = sum([
            choose(num_local_features - r, s) for s in range(1, limd+1)
        ])
        qnum = sum([
            choose(r, s) * q[s] for s in range(limn, r)
        ])
        q[r] = qnum / qden
    # Check that the checksum is satisfied
    checksum = sum([
        choose(num_local_features, i) * q[i] 
        for i in range((num_local_features - k), num_local_features)
    ])
    assert(np.isclose(checksum, 1.0))
    return q

_all_q_values = [get_q_values_for_k(_k, num_DSA_features) for _k in range(1, k+1)]
q_values = np.vstack(_all_q_values)

# %% [markdown]
# ### Take a single sample review

# %%
q_values.shape
# Out:
# (2, 1004)

# %%
sample_review_oh = oh_test.iloc[0]
print(f'sample review: {test_reviews_ss[0]}')
all_features_set = set(range(1, num_DSA_features + 1))
# Out:
# sample review: australian actor/director john polson and award-winning english cinematographer giles nuttgens make aaaa terrific effort at disguising the obvious with energy and innovation .

# %% [markdown]
# ## The Joint Shapley calculation function

# %%
np.shape(q_values)
# Out:
# (2, 1004)

# %%
def calculate_phi_t(
    review_oh,
    value_function,
    coalition_vc,
    num_features,
    q_values,
    num_sampling_iterations,
):
    coalition_size = len(coalition_vc)
    p_values = np.zeros((num_features - coalition_size + 1), dtype=np.longdouble)
    for i in range(1, num_features - coalition_size + 2):
        q_value = q_values[k-1, i-1]
        num_ft_choose_len = choose((num_features - coalition_size), (i - 1))
        p_values[i - 1] = num_ft_choose_len * q_value
    hat_p_values = p_values / np.sum(p_values)
    estimates = np.zeros(num_sampling_iterations)

    for itr in range(0, num_sampling_iterations):
        U = np.random.uniform(0, 1, 1)
        X = sum(U > hat_p_values.cumsum())
        S = set()
        for w in range(1, X + 1):
            possible_next = set(range(1, num_features + 1)).difference(
                set(coalition_vc).union(S))
            r = random.sample(possible_next, 1)
            S = S.union(set(r))

        z = np.random.randint(0, 2, num_features)
        xminusT = np.copy(review_oh)
        xplusT = np.copy(review_oh)
        for h in set(range(0, num_features)).difference(S):
            xminusT[h] = z[h]
        for h in set(range(0, num_features)).difference(S.union(set(coalition_vc))):
            xplusT[h] = z[h]

        estimates[itr] = value_function(xplusT) - value_function(xminusT)
    return np.mean(estimates) * np.sum(p_values)

# %% [markdown]
# #### We use a 'value function' to give us the value of a given coalition; in this case the 'value' is the prediction it receives from our ML model

# %%
value_f = lambda oh: model.predict(oh[None, :])[0][0]

# %% [markdown]
# #### We look at our target vocabulary, from Socher et al and DSA

# %%
# Obtain bigrams used in Dhamdhere et al as strings
t2dsa = target_vocab["t2dsa"]
# Vectorize bigrams
t2dsa_vc = ss_to_vc(t2dsa, DSA_vectorizer)
# Add both bigrams and single words from bigrams to list of coalitions
DSA_coalitions = [cln for cln in t2dsa_vc] + [[word] for cln in t2dsa_vc for word in cln]

# %% [markdown]
# #### We can now calculate Joint Shapley values for the Dhamdhere et al coalitions

# %%
test_reviews_vc = ss_to_vc(test_reviews_ss, DSA_vectorizer)
num_review = 38 # sets the review to be analysed
sample_review_oh = oh_test.iloc[num_review]
print(f'test_reviews_vc[num_review] = {test_reviews_vc[num_review]}')

num_times_to_loop = 60

with open("results/250528-review-38-convergence.txt", "a") as a_writer:
    a_writer.write(f'test_reviews_vc[num_review] = {test_reviews_vc[num_review]}\n')

    for loop_num in range(num_times_to_loop+1):
        a_writer.write(f'loop number = {loop_num}\n')
        for coalition in DSA_coalitions:
            js = calculate_phi_t(
                sample_review_oh,
                value_f,
                coalition,
                num_DSA_features,
                q_values,
                num_sampling_iterations
            )
            a_writer.write(f'k = {k}, coalition {coalition}: local jShapley = {js}\n')
# Out:
# test_reviews_vc[num_review] = [44, 101, 434, 447, 677, 860, 946]

# %% [markdown]
# #### Iterate through all the reviews in the test set, calculating local Joint Shapleys for the DSA features

# %%
for n, review_oh in enumerate(oh_test.iloc):
    for coalition in DSA_coalitions:
        js = calculate_phi_t(
            review_oh,
            value_f,
            coalition,
            num_DSA_features,
            q_values,
            num_sampling_iterations
        )
        print(f'k = {k}, review {n}, coalition {coalition}: local jShapley = {js}')
# Out:
# k = 2, review 0, coalition [209, 978]: local jShapley = -4.7900065620387405e-06
# k = 2, review 0, coalition [101, 434]: local jShapley = -4.907525153184e-06
# k = 2, review 0, coalition [3, 174]: local jShapley = 4.838098440561936e-10
# k = 2, review 0, coalition [269, 1003]: local jShapley = -2.395566742484094e-07
# k = 2, review 0, coalition [455, 848]: local jShapley = -4.6522446590037647e-07
# k = 2, review 0, coalition [209]: local jShapley = 0.0001314929815047722
# k = 2, review 0, coalition [978]: local jShapley = -0.00022204356783689076
# k = 2, review 0, coalition [101]: local jShapley = -3.309043209693446e-05
# k = 2, review 0, coalition [434]: local jShapley = -3.203610016164253e-05
# k = 2, review 0, coalition [3]: local jShapley = 3.4222717388386948e-06
# k = 2, review 0, coalition [174]: local jShapley = -3.0959593311031405e-08
# k = 2, review 0, coalition [269]: local jShapley = -0.00014270376774006753
# k = 2, review 0, coalition [1003]: local jShapley = -4.90002941774388e-05
# k = 2, review 0, coalition [455]: local jShapley = -5.800454647500213e-05
# k = 2, review 0, coalition [848]: local jShapley = 0.00026339935846651216
# k = 2, review 1, coalition [209, 978]: local jShapley = -1.244901729957081e-06
# k = 2, review 1, coalition [101, 434]: local jShapley = -1.9497536715464603e-07
# k = 2, review 1, coalition [3, 174]: local jShapley = -1.034055039869372e-06
# k = 2, review 1, coalition [269, 1003]: local jShapley = -6.19607007114698e-07
# k = 2, review 1, coalition [455, 848]: local jShapley = -7.788158465294824e-09
# k = 2, review 1, coalition [209]: local jShapley = 4.63500506442515e-05
# k = 2, review 1, coalition [978]: local jShapley = -0.0002720672343563104
# k = 2, review 1, coalition [101]: local jShapley = -0.0006412256723190719
# k = 2, review 1, coalition [434]: local jShapley = -3.5087837594311046e-05
# k = 2, review 1, coalition [3]: local jShapley = -2.021328819480563e-08
# k = 2, review 1, coalition [174]: local jShapley = 3.224104755207341e-06
# k = 2, review 1, coalition [269]: local jShapley = -1.562465855424514e-05
# k = 2, review 1, coalition [1003]: local jShapley = -5.918399610557582e-05
# k = 2, review 1, coalition [455]: local jShapley = 0.0003223888976223658
# k = 2, review 1, coalition [848]: local jShapley = -0.00046736192679280967
# k = 2, review 2, coalition [209, 978]: local jShapley = 6.316880929279841e-06
# k = 2, review 2, coalition [101, 434]: local jShapley = -5.022500792587939e-06
# k = 2, review 2, coalition [3, 174]: local jShapley = -1.0018403843992887e-07
# k = 2, review 2, coalition [269, 1003]: local jShapley = -1.9842103726353405e-07
# k = 2, review 2, coalition [455, 848]: local jShapley = -6.792808212949948e-08
# k = 2, review 2, coalition [209]: local jShapley = 4.914268272022879e-05
# k = 2, review 2, coalition [978]: local jShapley = -0.00014331860991136013
# k = 2, review 2, coalition [101]: local jShapley = 0.0
# k = 2, review 2, coalition [434]: local jShapley = -4.885381180412835e-05
# k = 2, review 2, coalition [3]: local jShapley = -1.549813360472196e-05
# k = 2, review 2, coalition [174]: local jShapley = -1.4422223771061738e-07
# k = 2, review 2, coalition [269]: local jShapley = -0.0001965917117623326
# k = 2, review 2, coalition [1003]: local jShapley = -2.8364190049191196e-05
# k = 2, review 2, coalition [455]: local jShapley = 0.00020553314934784747
# k = 2, review 2, coalition [848]: local jShapley = -2.020603870325897e-05
# k = 2, review 3, coalition [209, 978]: local jShapley = -8.186103862271144e-06
# k = 2, review 3, coalition [101, 434]: local jShapley = -6.745213124534917e-05
# k = 2, review 3, coalition [3, 174]: local jShapley = 1.7047688868525424e-06
# k = 2, review 3, coalition [269, 1003]: local jShapley = -2.0709728179867446e-05
# k = 2, review 3, coalition [455, 848]: local jShapley = 1.1232117539368492e-06
# k = 2, review 3, coalition [209]: local jShapley = 9.082401816436318e-05
# k = 2, review 3, coalition [978]: local jShapley = -0.00015143424512157458
# k = 2, review 3, coalition [101]: local jShapley = -0.000356428885179709
# k = 2, review 3, coalition [434]: local jShapley = -2.101422907850782e-05
# k = 2, review 3, coalition [3]: local jShapley = 3.19685093139869e-05
# k = 2, review 3, coalition [174]: local jShapley = 2.137013646938092e-05
# k = 2, review 3, coalition [269]: local jShapley = -0.0002804626146520901
# k = 2, review 3, coalition [1003]: local jShapley = -2.0575592195866955e-05
# k = 2, review 3, coalition [455]: local jShapley = 0.000352308999133742
# k = 2, review 3, coalition [848]: local jShapley = -0.0006421326689996948
# k = 2, review 4, coalition [209, 978]: local jShapley = 0.0
# k = 2, review 4, coalition [101, 434]: local jShapley = -1.2829398039159866e-06
# k = 2, review 4, coalition [3, 174]: local jShapley = -9.61017453777035e-07
# k = 2, review 4, coalition [269, 1003]: local jShapley = -2.7988694484653274e-06
# k = 2, review 4, coalition [455, 848]: local jShapley = 3.220757532602378e-07
# k = 2, review 4, coalition [209]: local jShapley = 8.541943692819212e-05
# k = 2, review 4, coalition [978]: local jShapley = -0.0003709389130866212
# k = 2, review 4, coalition [101]: local jShapley = -0.0002362286905903088
# k = 2, review 4, coalition [434]: local jShapley = -4.1018731916769636e-05
# k = 2, review 4, coalition [3]: local jShapley = -2.3614152611547715e-05
# k = 2, review 4, coalition [174]: local jShapley = 2.814508482821037e-09
# k = 2, review 4, coalition [269]: local jShapley = -0.00015463779543604378
# k = 2, review 4, coalition [1003]: local jShapley = -2.0930220264702407e-05
# k = 2, review 4, coalition [455]: local jShapley = 0.00028117310746773075
# k = 2, review 4, coalition [848]: local jShapley = -0.0006506982417705494
# k = 2, review 5, coalition [209, 978]: local jShapley = 5.398609845261185e-08
# k = 2, review 5, coalition [101, 434]: local jShapley = -9.288848099756394e-06
# k = 2, review 5, coalition [3, 174]: local jShapley = 2.044238194018605e-06
# k = 2, review 5, coalition [269, 1003]: local jShapley = -4.838098440561936e-10
# k = 2, review 5, coalition [455, 848]: local jShapley = 3.605681364629525e-07
# k = 2, review 5, coalition [209]: local jShapley = 0.0
# k = 2, review 5, coalition [978]: local jShapley = -0.00010981350689795672
# k = 2, review 5, coalition [101]: local jShapley = -0.00010231386524886878
# k = 2, review 5, coalition [434]: local jShapley = 3.8626143841964225e-06
# k = 2, review 5, coalition [3]: local jShapley = 1.299850891943351e-05
# k = 2, review 5, coalition [174]: local jShapley = 4.3363132194823716e-05
# k = 2, review 5, coalition [269]: local jShapley = -0.00030595754123524904
# k = 2, review 5, coalition [1003]: local jShapley = -1.4613269195350197e-05
# k = 2, review 5, coalition [455]: local jShapley = 0.0004670361261138892
# k = 2, review 5, coalition [848]: local jShapley = -0.0005094713660348083
# k = 2, review 6, coalition [209, 978]: local jShapley = -9.723155936597571e-06
# k = 2, review 6, coalition [101, 434]: local jShapley = -9.733079938520772e-06
# k = 2, review 6, coalition [3, 174]: local jShapley = 1.298026410882471e-10
# k = 2, review 6, coalition [269, 1003]: local jShapley = -2.760421316162984e-05
# k = 2, review 6, coalition [455, 848]: local jShapley = -3.950451339648028e-05
# k = 2, review 6, coalition [209]: local jShapley = 0.0003432163456833773
# k = 2, review 6, coalition [978]: local jShapley = -0.000228431691855604
# k = 2, review 6, coalition [101]: local jShapley = -0.0003605455729205819
# k = 2, review 6, coalition [434]: local jShapley = -1.8680788325909577e-05
# k = 2, review 6, coalition [3]: local jShapley = -8.615295754051037e-06
# k = 2, review 6, coalition [174]: local jShapley = -5.172768082949615e-06
# k = 2, review 6, coalition [269]: local jShapley = -0.0004335295732021764
# k = 2, review 6, coalition [1003]: local jShapley = -2.552793309173018e-05
# k = 2, review 6, coalition [455]: local jShapley = 0.00046548243214323615
# k = 2, review 6, coalition [848]: local jShapley = -0.0003769779954093967
# k = 2, review 7, coalition [209, 978]: local jShapley = 1.8229010904829461e-07
# k = 2, review 7, coalition [101, 434]: local jShapley = -1.2579055945461033e-08
# k = 2, review 7, coalition [3, 174]: local jShapley = 2.197228306901253e-06
# k = 2, review 7, coalition [269, 1003]: local jShapley = -1.6401153713504965e-07
# k = 2, review 7, coalition [455, 848]: local jShapley = 8.247872219069e-06
# k = 2, review 7, coalition [209]: local jShapley = 1.564124709666662e-05
# k = 2, review 7, coalition [978]: local jShapley = -2.1985106572877317e-05
# k = 2, review 7, coalition [101]: local jShapley = -2.0051070160432126e-05
# k = 2, review 7, coalition [434]: local jShapley = -3.307559196129777e-06
# k = 2, review 7, coalition [3]: local jShapley = -2.169474311439961e-06
# k = 2, review 7, coalition [174]: local jShapley = -2.3300718712324462e-06
# k = 2, review 7, coalition [269]: local jShapley = -1.089538877767945e-05
# k = 2, review 7, coalition [1003]: local jShapley = -2.4813133225229478e-05
# k = 2, review 7, coalition [455]: local jShapley = 9.419392298779424e-05
# k = 2, review 7, coalition [848]: local jShapley = -2.3103873694798677e-05
# k = 2, review 8, coalition [209, 978]: local jShapley = -5.1247262725649835e-06
# k = 2, review 8, coalition [101, 434]: local jShapley = -4.90046270948479e-06
# k = 2, review 8, coalition [3, 174]: local jShapley = 3.9448733661532624e-06
# k = 2, review 8, coalition [269, 1003]: local jShapley = -1.2471762262361499e-05
# k = 2, review 8, coalition [455, 848]: local jShapley = -3.534790242211184e-05
# k = 2, review 8, coalition [209]: local jShapley = 0.00015855469571870429
# k = 2, review 8, coalition [978]: local jShapley = -8.035097623537858e-05
# k = 2, review 8, coalition [101]: local jShapley = -2.1586981887918686e-06
# k = 2, review 8, coalition [434]: local jShapley = -0.00011985226163922845
# k = 2, review 8, coalition [3]: local jShapley = 2.252033226936045e-06
# k = 2, review 8, coalition [174]: local jShapley = 1.4669559365006617e-08
# k = 2, review 8, coalition [269]: local jShapley = -0.00019854259258160676
# k = 2, review 8, coalition [1003]: local jShapley = -3.757752621177378e-05
# k = 2, review 8, coalition [455]: local jShapley = 0.0003147921980746884
# k = 2, review 8, coalition [848]: local jShapley = -0.00017162386585868378
# k = 2, review 9, coalition [209, 978]: local jShapley = 7.533391281558892e-07
# k = 2, review 9, coalition [101, 434]: local jShapley = -9.39625978525692e-06
# k = 2, review 9, coalition [3, 174]: local jShapley = 5.754977096248918e-08
# k = 2, review 9, coalition [269, 1003]: local jShapley = -2.2264321311100938e-05
# k = 2, review 9, coalition [455, 848]: local jShapley = 3.6313002758963105e-05
# k = 2, review 9, coalition [209]: local jShapley = 0.00016969524524286462
# k = 2, review 9, coalition [978]: local jShapley = -8.430634146730433e-05
# k = 2, review 9, coalition [101]: local jShapley = -0.0008149876690992734
# k = 2, review 9, coalition [434]: local jShapley = -1.7950380730549595e-05
# k = 2, review 9, coalition [3]: local jShapley = 0.0001259416639621514
# k = 2, review 9, coalition [174]: local jShapley = 1.442810865243491e-05
# k = 2, review 9, coalition [269]: local jShapley = -0.0001301822327203363
# k = 2, review 9, coalition [1003]: local jShapley = -3.603978112252338e-05
# k = 2, review 9, coalition [455]: local jShapley = 0.00032764341438352095
# k = 2, review 9, coalition [848]: local jShapley = -3.870772194389812e-05
# k = 2, review 10, coalition [209, 978]: local jShapley = 1.6104772983060152e-05
# k = 2, review 10, coalition [101, 434]: local jShapley = -1.8231713159812118e-05
# k = 2, review 10, coalition [3, 174]: local jShapley = 6.541587001363745e-06
# k = 2, review 10, coalition [269, 1003]: local jShapley = -3.5147133137068616e-06
# k = 2, review 10, coalition [455, 848]: local jShapley = -5.067518118553359e-05
# k = 2, review 10, coalition [209]: local jShapley = 0.00016344140739403627
# k = 2, review 10, coalition [978]: local jShapley = -0.00022299781414477084
# k = 2, review 10, coalition [101]: local jShapley = -0.0005554036327456326
# k = 2, review 10, coalition [434]: local jShapley = -8.446817570506654e-05
# k = 2, review 10, coalition [3]: local jShapley = 3.847953353645e-05
# k = 2, review 10, coalition [174]: local jShapley = 0.0
# k = 2, review 10, coalition [269]: local jShapley = -0.0005503471976799729
# k = 2, review 10, coalition [1003]: local jShapley = -3.9290749399602715e-05
# k = 2, review 10, coalition [455]: local jShapley = 0.0009348136193485942
# k = 2, review 10, coalition [848]: local jShapley = -0.000334932692845552
# k = 2, review 11, coalition [209, 978]: local jShapley = 1.1118021017851924e-05
# k = 2, review 11, coalition [101, 434]: local jShapley = -2.311080563447774e-05
# k = 2, review 11, coalition [3, 174]: local jShapley = 2.9358997366141702e-08
# k = 2, review 11, coalition [269, 1003]: local jShapley = -4.3218084356334335e-05
# k = 2, review 11, coalition [455, 848]: local jShapley = 1.9351626746641315e-06
# k = 2, review 11, coalition [209]: local jShapley = 0.0001378027276579139
# k = 2, review 11, coalition [978]: local jShapley = -5.314679012178886e-05
# k = 2, review 11, coalition [101]: local jShapley = -3.3475593318401727e-06
# k = 2, review 11, coalition [434]: local jShapley = -3.46464714913232e-05
# k = 2, review 11, coalition [3]: local jShapley = 2.86383061177908e-05
# k = 2, review 11, coalition [174]: local jShapley = -1.4038427159767961e-06
# k = 2, review 11, coalition [269]: local jShapley = -0.0003030834163454737
# k = 2, review 11, coalition [1003]: local jShapley = -1.204336708612706e-05
# k = 2, review 11, coalition [455]: local jShapley = 0.0007715659439551253
# k = 2, review 11, coalition [848]: local jShapley = 0.0
# k = 2, review 12, coalition [209, 978]: local jShapley = -1.696414316862499e-06
# k = 2, review 12, coalition [101, 434]: local jShapley = -5.9955839918661326e-06
# k = 2, review 12, coalition [3, 174]: local jShapley = -9.134565860582915e-08
# k = 2, review 12, coalition [269, 1003]: local jShapley = -2.0485582619188243e-05
# k = 2, review 12, coalition [455, 848]: local jShapley = 4.440200244546014e-06
# k = 2, review 12, coalition [209]: local jShapley = 0.00014105749349795682
# k = 2, review 12, coalition [978]: local jShapley = -7.381069818232131e-05
# k = 2, review 12, coalition [101]: local jShapley = -0.0003203152871756135
# k = 2, review 12, coalition [434]: local jShapley = 2.0691711992817286e-05
# k = 2, review 12, coalition [3]: local jShapley = 4.4299832785234846e-05
# k = 2, review 12, coalition [174]: local jShapley = 1.3364437666268166e-05
# k = 2, review 12, coalition [269]: local jShapley = -4.033719442324773e-05
# k = 2, review 12, coalition [1003]: local jShapley = -1.6490546353391825e-05
# k = 2, review 12, coalition [455]: local jShapley = 0.0002553045335614434
# k = 2, review 12, coalition [848]: local jShapley = -0.00017387675196697824
# k = 2, review 13, coalition [209, 978]: local jShapley = 3.9483603371024976e-08
# k = 2, review 13, coalition [101, 434]: local jShapley = -3.779650613939412e-06
# k = 2, review 13, coalition [3, 174]: local jShapley = -3.104643170028892e-08
# k = 2, review 13, coalition [269, 1003]: local jShapley = -4.171105209281959e-05
# k = 2, review 13, coalition [455, 848]: local jShapley = 3.3235435239841214e-05
# k = 2, review 13, coalition [209]: local jShapley = 7.843052412408547e-07
# k = 2, review 13, coalition [978]: local jShapley = -4.419162114640322e-06
# k = 2, review 13, coalition [101]: local jShapley = -8.624993015096394e-05
# k = 2, review 13, coalition [434]: local jShapley = -2.7035486180892137e-06
# k = 2, review 13, coalition [3]: local jShapley = -4.595741621645938e-09
# k = 2, review 13, coalition [174]: local jShapley = 3.149307060072976e-06
# k = 2, review 13, coalition [269]: local jShapley = -1.633404262411981e-05
# k = 2, review 13, coalition [1003]: local jShapley = -2.1309411316660658e-05
# k = 2, review 13, coalition [455]: local jShapley = 0.0
# k = 2, review 13, coalition [848]: local jShapley = -0.0003816119556941577
# k = 2, review 14, coalition [209, 978]: local jShapley = -1.629167108586708e-05
# k = 2, review 14, coalition [101, 434]: local jShapley = -2.04043379661071e-05
# k = 2, review 14, coalition [3, 174]: local jShapley = -2.249467969819223e-06
# k = 2, review 14, coalition [269, 1003]: local jShapley = -5.302661737133372e-07
# k = 2, review 14, coalition [455, 848]: local jShapley = 2.815065278001111e-07
# k = 2, review 14, coalition [209]: local jShapley = 0.00019631849121915933
# k = 2, review 14, coalition [978]: local jShapley = -6.375765767829586e-05
# k = 2, review 14, coalition [101]: local jShapley = -0.0005062735300254405
# k = 2, review 14, coalition [434]: local jShapley = -5.127829764173906e-05
# k = 2, review 14, coalition [3]: local jShapley = -2.4403835461318626e-05
# k = 2, review 14, coalition [174]: local jShapley = -1.279322037645926e-09
# k = 2, review 14, coalition [269]: local jShapley = -0.00023838178957966686
# k = 2, review 14, coalition [1003]: local jShapley = -1.15659241016776e-06
# k = 2, review 14, coalition [455]: local jShapley = 0.0004831339632457916
# k = 2, review 14, coalition [848]: local jShapley = -0.0010857734918586098
# k = 2, review 15, coalition [209, 978]: local jShapley = -1.1059385624800332e-05
# k = 2, review 15, coalition [101, 434]: local jShapley = -4.1974545554108685e-05
# k = 2, review 15, coalition [3, 174]: local jShapley = 4.0179830275921186e-08
# k = 2, review 15, coalition [269, 1003]: local jShapley = -2.7875943190507987e-06
# k = 2, review 15, coalition [455, 848]: local jShapley = 4.9339075399851865e-05
# k = 2, review 15, coalition [209]: local jShapley = 0.00013370237259505494
# k = 2, review 15, coalition [978]: local jShapley = -0.00026387279290857697
# k = 2, review 15, coalition [101]: local jShapley = -2.2212697963374525e-05
# k = 2, review 15, coalition [434]: local jShapley = -3.4658539762544996e-05
# k = 2, review 15, coalition [3]: local jShapley = 6.685357436533107e-05
# k = 2, review 15, coalition [174]: local jShapley = -3.289563399466891e-07
# k = 2, review 15, coalition [269]: local jShapley = -0.0001581922637854392
# k = 2, review 15, coalition [1003]: local jShapley = -9.575384299236384e-06
# k = 2, review 15, coalition [455]: local jShapley = 0.00038944447693744117
# k = 2, review 15, coalition [848]: local jShapley = -0.0008074099888058889
# k = 2, review 16, coalition [209, 978]: local jShapley = 2.1521513897233344e-06
# k = 2, review 16, coalition [101, 434]: local jShapley = -4.5768411247715917e-07
# k = 2, review 16, coalition [3, 174]: local jShapley = 2.4112610618156734e-06
# k = 2, review 16, coalition [269, 1003]: local jShapley = -2.418235003714142e-05
# k = 2, review 16, coalition [455, 848]: local jShapley = -2.926129137812255e-06
# k = 2, review 16, coalition [209]: local jShapley = 0.00013214185557353442
# k = 2, review 16, coalition [978]: local jShapley = -9.125830535207605e-09
# k = 2, review 16, coalition [101]: local jShapley = -2.6696977569731026e-05
# k = 2, review 16, coalition [434]: local jShapley = -5.931960424156629e-06
# k = 2, review 16, coalition [3]: local jShapley = 2.218864670906678e-05
# k = 2, review 16, coalition [174]: local jShapley = -1.3825206820160305e-07
# k = 2, review 16, coalition [269]: local jShapley = -0.00016385607831050525
# k = 2, review 16, coalition [1003]: local jShapley = 7.942031209705909e-07
# k = 2, review 16, coalition [455]: local jShapley = 4.185677313956356e-05
# k = 2, review 16, coalition [848]: local jShapley = -0.00011935673756998026
# k = 2, review 17, coalition [209, 978]: local jShapley = -1.2962829254078535e-05
# k = 2, review 17, coalition [101, 434]: local jShapley = -6.587012025624582e-07
# k = 2, review 17, coalition [3, 174]: local jShapley = -2.5494654738543597e-06
# k = 2, review 17, coalition [269, 1003]: local jShapley = -4.288561259154694e-07
# k = 2, review 17, coalition [455, 848]: local jShapley = 4.509597456567831e-06
# k = 2, review 17, coalition [209]: local jShapley = 4.282692568477839e-05
# k = 2, review 17, coalition [978]: local jShapley = -3.2904248096389057e-05
# k = 2, review 17, coalition [101]: local jShapley = -0.0003949615532247892
# k = 2, review 17, coalition [434]: local jShapley = -4.855581505749268e-06
# k = 2, review 17, coalition [3]: local jShapley = -5.456265846491952e-06
# k = 2, review 17, coalition [174]: local jShapley = -3.267388484147695e-06
# k = 2, review 17, coalition [269]: local jShapley = -0.00022744904459848813
# k = 2, review 17, coalition [1003]: local jShapley = -5.56176727052982e-06
# k = 2, review 17, coalition [455]: local jShapley = 6.11425528570759e-05
# k = 2, review 17, coalition [848]: local jShapley = -0.0001649255488899093
# k = 2, review 18, coalition [209, 978]: local jShapley = -1.1833752780812518e-05
# k = 2, review 18, coalition [101, 434]: local jShapley = -1.4545565957947977e-06
# k = 2, review 18, coalition [3, 174]: local jShapley = 1.8787457267511397e-06
# k = 2, review 18, coalition [269, 1003]: local jShapley = -3.6967255271008264e-05
# k = 2, review 18, coalition [455, 848]: local jShapley = 9.580385421652604e-05
# k = 2, review 18, coalition [209]: local jShapley = 0.00031237274423709247
# k = 2, review 18, coalition [978]: local jShapley = -3.308463250369713e-05
# k = 2, review 18, coalition [101]: local jShapley = -0.00021240933472392264
# k = 2, review 18, coalition [434]: local jShapley = -1.9169361412086555e-06
# k = 2, review 18, coalition [3]: local jShapley = 1.9149745140842653e-06
# k = 2, review 18, coalition [174]: local jShapley = 1.3560813599046815e-08
# k = 2, review 18, coalition [269]: local jShapley = -0.00011392158053710947
# k = 2, review 18, coalition [1003]: local jShapley = 0.0
# k = 2, review 18, coalition [455]: local jShapley = 0.0006918784241284699
# k = 2, review 18, coalition [848]: local jShapley = 0.0007005798182556546
# k = 2, review 19, coalition [209, 978]: local jShapley = 2.208236750889546e-05
# k = 2, review 19, coalition [101, 434]: local jShapley = -2.3600480197863105e-11
# k = 2, review 19, coalition [3, 174]: local jShapley = -1.0789230927975394e-05
# k = 2, review 19, coalition [269, 1003]: local jShapley = -3.0612890879054165e-06
# k = 2, review 19, coalition [455, 848]: local jShapley = 3.936300491721389e-06
# k = 2, review 19, coalition [209]: local jShapley = 0.00015133330661280434
# k = 2, review 19, coalition [978]: local jShapley = -0.0003880650692723834
# k = 2, review 19, coalition [101]: local jShapley = -0.0005079135355895669
# k = 2, review 19, coalition [434]: local jShapley = -0.00015834740290453776
# k = 2, review 19, coalition [3]: local jShapley = -2.0733034094633248e-05
# k = 2, review 19, coalition [174]: local jShapley = -8.719347279779572e-06
# k = 2, review 19, coalition [269]: local jShapley = -2.064041117910768e-05
# k = 2, review 19, coalition [1003]: local jShapley = 0.0
# k = 2, review 19, coalition [455]: local jShapley = 0.0004957069696555041
# k = 2, review 19, coalition [848]: local jShapley = -0.0008004340163108774
# k = 2, review 20, coalition [209, 978]: local jShapley = 2.9358997366141702e-08
# k = 2, review 20, coalition [101, 434]: local jShapley = -2.362325466125404e-06
# k = 2, review 20, coalition [3, 174]: local jShapley = -3.0957995440431265e-08
# k = 2, review 20, coalition [269, 1003]: local jShapley = -1.0409198295469254e-05
# k = 2, review 20, coalition [455, 848]: local jShapley = 1.463510617981867e-05
# k = 2, review 20, coalition [209]: local jShapley = 9.43958852934706e-05
# k = 2, review 20, coalition [978]: local jShapley = -0.00024375140268014225
# k = 2, review 20, coalition [101]: local jShapley = -0.0002503269047333027
# k = 2, review 20, coalition [434]: local jShapley = -2.2051076945951922e-05
# k = 2, review 20, coalition [3]: local jShapley = -2.370191410333023e-05
# k = 2, review 20, coalition [174]: local jShapley = 2.554379668499699e-08
# k = 2, review 20, coalition [269]: local jShapley = -0.00017219324945357207
# k = 2, review 20, coalition [1003]: local jShapley = -3.226394741654727e-05
# k = 2, review 20, coalition [455]: local jShapley = 0.00044077023742677686
# k = 2, review 20, coalition [848]: local jShapley = -0.0003082408325639716
# k = 2, review 21, coalition [209, 978]: local jShapley = -2.6614167117209434e-05
# k = 2, review 21, coalition [101, 434]: local jShapley = -6.689031001399895e-06
# k = 2, review 21, coalition [3, 174]: local jShapley = 1.911638896026911e-09
# k = 2, review 21, coalition [269, 1003]: local jShapley = -1.1324513419343127e-05
# k = 2, review 21, coalition [455, 848]: local jShapley = -7.886971637633797e-06
# k = 2, review 21, coalition [209]: local jShapley = 0.0001292593724464465
# k = 2, review 21, coalition [978]: local jShapley = -3.089247154812292e-05
# k = 2, review 21, coalition [101]: local jShapley = -8.01884170484617e-05
# k = 2, review 21, coalition [434]: local jShapley = -1.239543651088722e-05
# k = 2, review 21, coalition [3]: local jShapley = -3.4392696643122175e-05
# k = 2, review 21, coalition [174]: local jShapley = -8.621948228646797e-06
# k = 2, review 21, coalition [269]: local jShapley = -0.00010427481006817245
# k = 2, review 21, coalition [1003]: local jShapley = -1.1078331829062816e-05
# k = 2, review 21, coalition [455]: local jShapley = 0.00017864094723517169
# k = 2, review 21, coalition [848]: local jShapley = -0.0003895670359886476
# k = 2, review 22, coalition [209, 978]: local jShapley = -1.5569201385809995e-05
# k = 2, review 22, coalition [101, 434]: local jShapley = -5.066851994999774e-06
# k = 2, review 22, coalition [3, 174]: local jShapley = -2.577172437606651e-08
# k = 2, review 22, coalition [269, 1003]: local jShapley = -1.197730270161602e-05
# k = 2, review 22, coalition [455, 848]: local jShapley = 8.825871579594864e-07
# k = 2, review 22, coalition [209]: local jShapley = 0.000227964312871184
# k = 2, review 22, coalition [978]: local jShapley = -6.573156629424767e-05
# k = 2, review 22, coalition [101]: local jShapley = -0.00018439179830286557
# k = 2, review 22, coalition [434]: local jShapley = -1.4096380448073322e-05
# k = 2, review 22, coalition [3]: local jShapley = -3.337252260623539e-05
# k = 2, review 22, coalition [174]: local jShapley = 3.0121040359422427e-05
# k = 2, review 22, coalition [269]: local jShapley = -5.013151336719325e-06
# k = 2, review 22, coalition [1003]: local jShapley = -8.190475549416746e-05
# k = 2, review 22, coalition [455]: local jShapley = 0.0007928252058479104
# k = 2, review 22, coalition [848]: local jShapley = -0.000930414414657741
# k = 2, review 23, coalition [209, 978]: local jShapley = 9.308619402042155e-07
# k = 2, review 23, coalition [101, 434]: local jShapley = -2.2457803947883067e-05
# k = 2, review 23, coalition [3, 174]: local jShapley = 2.34227685819732e-06
# k = 2, review 23, coalition [269, 1003]: local jShapley = -2.5736305955409566e-05
# k = 2, review 23, coalition [455, 848]: local jShapley = -8.846310775470224e-05
# k = 2, review 23, coalition [209]: local jShapley = 7.628946991839613e-05
# k = 2, review 23, coalition [978]: local jShapley = -0.00011937912570563906
# k = 2, review 23, coalition [101]: local jShapley = -0.0003949891865808024
# k = 2, review 23, coalition [434]: local jShapley = -4.103318825579504e-05
# k = 2, review 23, coalition [3]: local jShapley = 5.477779778758365e-05
# k = 2, review 23, coalition [174]: local jShapley = 3.340966558939504e-05
# k = 2, review 23, coalition [269]: local jShapley = -8.264983264889246e-05
# k = 2, review 23, coalition [1003]: local jShapley = -4.139242188396601e-05
# k = 2, review 23, coalition [455]: local jShapley = 0.00019448373019683547
# k = 2, review 23, coalition [848]: local jShapley = -0.0003331106397554688
# k = 2, review 24, coalition [209, 978]: local jShapley = 1.298026410882471e-10
# k = 2, review 24, coalition [101, 434]: local jShapley = -3.408617354977368e-07
# k = 2, review 24, coalition [3, 174]: local jShapley = -4.802697720265142e-09
# k = 2, review 24, coalition [269, 1003]: local jShapley = -2.4616303866779628e-05
# k = 2, review 24, coalition [455, 848]: local jShapley = 4.915972945070825e-05
# k = 2, review 24, coalition [209]: local jShapley = 0.00023450676577170526
# k = 2, review 24, coalition [978]: local jShapley = -9.813269967729851e-05
# k = 2, review 24, coalition [101]: local jShapley = -0.00018515803481994482
# k = 2, review 24, coalition [434]: local jShapley = -4.680382617100452e-05
# k = 2, review 24, coalition [3]: local jShapley = -1.1744346881861286e-05
# k = 2, review 24, coalition [174]: local jShapley = -1.8742366359988263e-05
# k = 2, review 24, coalition [269]: local jShapley = -0.00020167155842128117
# k = 2, review 24, coalition [1003]: local jShapley = -1.192635176375038e-05
# k = 2, review 24, coalition [455]: local jShapley = 0.0006497817354627799
# k = 2, review 24, coalition [848]: local jShapley = -0.0003399179976059186
# k = 2, review 25, coalition [209, 978]: local jShapley = -7.968914543130258e-06
# k = 2, review 25, coalition [101, 434]: local jShapley = -2.8300940637911105e-05
# k = 2, review 25, coalition [3, 174]: local jShapley = -3.776076831658097e-10
# k = 2, review 25, coalition [269, 1003]: local jShapley = -1.8701457117670386e-05
# k = 2, review 25, coalition [455, 848]: local jShapley = 4.2116065833615165e-05
# k = 2, review 25, coalition [209]: local jShapley = 0.0
# k = 2, review 25, coalition [978]: local jShapley = -0.0001832882977572601
# k = 2, review 25, coalition [101]: local jShapley = -0.00011391816901167575
# k = 2, review 25, coalition [434]: local jShapley = -3.142825161748903e-05
# k = 2, review 25, coalition [3]: local jShapley = 1.536406065517667e-05
# k = 2, review 25, coalition [174]: local jShapley = -1.053914023426298e-05
# k = 2, review 25, coalition [269]: local jShapley = -0.00011686581227454781
# k = 2, review 25, coalition [1003]: local jShapley = -1.706274445676293e-06
# k = 2, review 25, coalition [455]: local jShapley = 3.090594707358612e-05
# k = 2, review 25, coalition [848]: local jShapley = -0.000121661649441139
# k = 2, review 26, coalition [209, 978]: local jShapley = 3.781516742343704e-06
# k = 2, review 26, coalition [101, 434]: local jShapley = -1.4212586782836327e-05
# k = 2, review 26, coalition [3, 174]: local jShapley = 1.8194200196537613e-07
# k = 2, review 26, coalition [269, 1003]: local jShapley = -3.602300595841181e-06
# k = 2, review 26, coalition [455, 848]: local jShapley = -3.892839027413015e-05
# k = 2, review 26, coalition [209]: local jShapley = 1.6246536996744828e-05
# k = 2, review 26, coalition [978]: local jShapley = -1.155586010164812e-05
# k = 2, review 26, coalition [101]: local jShapley = -4.423588568890577e-05
# k = 2, review 26, coalition [434]: local jShapley = -1.3906870210230037e-05
# k = 2, review 26, coalition [3]: local jShapley = 4.974004082367361e-07
# k = 2, review 26, coalition [174]: local jShapley = 1.4329430279264488e-05
# k = 2, review 26, coalition [269]: local jShapley = -0.00013036351265307075
# k = 2, review 26, coalition [1003]: local jShapley = -1.9784971176601774e-05
# k = 2, review 26, coalition [455]: local jShapley = 0.0003040304558058751
# k = 2, review 26, coalition [848]: local jShapley = -0.0002675955347499908
# k = 2, review 27, coalition [209, 978]: local jShapley = -3.296308569835787e-06
# k = 2, review 27, coalition [101, 434]: local jShapley = -1.2968463868725775e-07
# k = 2, review 27, coalition [3, 174]: local jShapley = -4.714844932728597e-06
# k = 2, review 27, coalition [269, 1003]: local jShapley = -2.4483138157263184e-07
# k = 2, review 27, coalition [455, 848]: local jShapley = 1.11558289871289e-06
# k = 2, review 27, coalition [209]: local jShapley = 7.880768741729837e-05
# k = 2, review 27, coalition [978]: local jShapley = -4.8995731262171206e-05
# k = 2, review 27, coalition [101]: local jShapley = -3.151072524484927e-05
# k = 2, review 27, coalition [434]: local jShapley = -2.8592847541386443e-06
# k = 2, review 27, coalition [3]: local jShapley = -2.8406748828976886e-05
# k = 2, review 27, coalition [174]: local jShapley = 4.514556894580786e-06
# k = 2, review 27, coalition [269]: local jShapley = -3.040138246193857e-05
# k = 2, review 27, coalition [1003]: local jShapley = -3.238816958640269e-06
# k = 2, review 27, coalition [455]: local jShapley = 0.00023070568677751961
# k = 2, review 27, coalition [848]: local jShapley = -0.0004783825185539067
# k = 2, review 28, coalition [209, 978]: local jShapley = -1.3342017893209588e-07
# k = 2, review 28, coalition [101, 434]: local jShapley = -1.1229338582825194e-05
# k = 2, review 28, coalition [3, 174]: local jShapley = -3.426943127851009e-06
# k = 2, review 28, coalition [269, 1003]: local jShapley = -5.55637315526385e-06
# k = 2, review 28, coalition [455, 848]: local jShapley = 1.4078040445228308e-06
# k = 2, review 28, coalition [209]: local jShapley = 0.0002222409245832316
# k = 2, review 28, coalition [978]: local jShapley = -0.00024822497862545044
# k = 2, review 28, coalition [101]: local jShapley = -0.00027772426847457696
# k = 2, review 28, coalition [434]: local jShapley = -3.911684913153728e-05
# k = 2, review 28, coalition [3]: local jShapley = 1.5825298893815946e-05
# k = 2, review 28, coalition [174]: local jShapley = -7.855037311145985e-08
# k = 2, review 28, coalition [269]: local jShapley = -3.254808484110843e-05
# k = 2, review 28, coalition [1003]: local jShapley = -3.233166619640666e-05
# k = 2, review 28, coalition [455]: local jShapley = 0.0014072314268341805
# k = 2, review 28, coalition [848]: local jShapley = -0.0010521850623364875
# k = 2, review 29, coalition [209, 978]: local jShapley = 9.493363961031027e-06
# k = 2, review 29, coalition [101, 434]: local jShapley = -8.5339336395473e-08
# k = 2, review 29, coalition [3, 174]: local jShapley = 3.7163086155570084e-07
# k = 2, review 29, coalition [269, 1003]: local jShapley = -8.64721594449704e-08
# k = 2, review 29, coalition [455, 848]: local jShapley = 3.0538879773153665e-05
# k = 2, review 29, coalition [209]: local jShapley = 2.2350182438353542e-05
# k = 2, review 29, coalition [978]: local jShapley = -0.00017014198449841057
# k = 2, review 29, coalition [101]: local jShapley = -0.00044384325424933824
# k = 2, review 29, coalition [434]: local jShapley = -5.7514736710855425e-05
# k = 2, review 29, coalition [3]: local jShapley = 0.0
# k = 2, review 29, coalition [174]: local jShapley = 1.1258033931284148e-08
# k = 2, review 29, coalition [269]: local jShapley = -0.0002297850439951617
# k = 2, review 29, coalition [1003]: local jShapley = -7.574823140833606e-05
# k = 2, review 29, coalition [455]: local jShapley = 0.0006104736276866145
# k = 2, review 29, coalition [848]: local jShapley = -0.0006045272109234325
# k = 2, review 30, coalition [209, 978]: local jShapley = 1.3806280915749916e-09
# k = 2, review 30, coalition [101, 434]: local jShapley = -5.316709098830541e-05
# k = 2, review 30, coalition [3, 174]: local jShapley = -2.3541478997368447e-08
# k = 2, review 30, coalition [269, 1003]: local jShapley = -9.281354947293574e-06
# k = 2, review 30, coalition [455, 848]: local jShapley = 4.7029856914291703e-07
# k = 2, review 30, coalition [209]: local jShapley = 0.00012887301719107742
# k = 2, review 30, coalition [978]: local jShapley = -1.0204981318029865e-05
# k = 2, review 30, coalition [101]: local jShapley = -0.0005988072341609138
# k = 2, review 30, coalition [434]: local jShapley = -6.210545591074406e-05
# k = 2, review 30, coalition [3]: local jShapley = 7.17253179728226e-05
# k = 2, review 30, coalition [174]: local jShapley = -3.742776024523337e-05
# k = 2, review 30, coalition [269]: local jShapley = -0.00015479310513141398
# k = 2, review 30, coalition [1003]: local jShapley = -2.0238107042335958e-05
# k = 2, review 30, coalition [455]: local jShapley = 0.0006158126223463222
# k = 2, review 30, coalition [848]: local jShapley = -0.00011376584440106004
# k = 2, review 31, coalition [209, 978]: local jShapley = 1.6280295654411706e-05
# k = 2, review 31, coalition [101, 434]: local jShapley = -4.8609324951653735e-05
# k = 2, review 31, coalition [3, 174]: local jShapley = -4.2864372159368864e-08
# k = 2, review 31, coalition [269, 1003]: local jShapley = -1.904653153888344e-05
# k = 2, review 31, coalition [455, 848]: local jShapley = 4.980263013177824e-05
# k = 2, review 31, coalition [209]: local jShapley = 2.7221542249233778e-05
# k = 2, review 31, coalition [978]: local jShapley = -0.0002297357048085765
# k = 2, review 31, coalition [101]: local jShapley = -4.938183065313274e-06
# k = 2, review 31, coalition [434]: local jShapley = -6.069461956762813e-05
# k = 2, review 31, coalition [3]: local jShapley = 0.0
# k = 2, review 31, coalition [174]: local jShapley = 3.2708255960221706e-05
# k = 2, review 31, coalition [269]: local jShapley = -7.675932225875556e-10
# k = 2, review 31, coalition [1003]: local jShapley = -3.0519932970760425e-05
# k = 2, review 31, coalition [455]: local jShapley = 0.0009004932896887348
# k = 2, review 31, coalition [848]: local jShapley = -0.000372512820345469
# k = 2, review 32, coalition [209, 978]: local jShapley = 6.441161058001788e-07
# k = 2, review 32, coalition [101, 434]: local jShapley = -1.982711742142776e-06
# k = 2, review 32, coalition [3, 174]: local jShapley = 9.428745846249278e-07
# k = 2, review 32, coalition [269, 1003]: local jShapley = -1.8091066098072952e-06
# k = 2, review 32, coalition [455, 848]: local jShapley = 3.771439337299217e-06
# k = 2, review 32, coalition [209]: local jShapley = 8.88987237858419e-05
# k = 2, review 32, coalition [978]: local jShapley = -6.16250278415401e-05
# k = 2, review 32, coalition [101]: local jShapley = -0.0005551274271177048
# k = 2, review 32, coalition [434]: local jShapley = -3.405555264213455e-06
# k = 2, review 32, coalition [3]: local jShapley = 6.534188480158073e-05
# k = 2, review 32, coalition [174]: local jShapley = 1.999435355009649e-05
# k = 2, review 32, coalition [269]: local jShapley = -0.00015520001482752121
# k = 2, review 32, coalition [1003]: local jShapley = -1.914974514084265e-05
# k = 2, review 32, coalition [455]: local jShapley = 0.001183824186993295
# k = 2, review 32, coalition [848]: local jShapley = -7.350899140177647e-06
# k = 2, review 33, coalition [209, 978]: local jShapley = -1.400570497342186e-07
# k = 2, review 33, coalition [101, 434]: local jShapley = -5.556615060185878e-07
# k = 2, review 33, coalition [3, 174]: local jShapley = 3.498234278408704e-06
# k = 2, review 33, coalition [269, 1003]: local jShapley = 2.3061209225341933e-07
# k = 2, review 33, coalition [455, 848]: local jShapley = 1.70412931383918e-05
# k = 2, review 33, coalition [209]: local jShapley = 9.152525721726484e-05
# k = 2, review 33, coalition [978]: local jShapley = 0.0
# k = 2, review 33, coalition [101]: local jShapley = -0.0005996665974176685
# k = 2, review 33, coalition [434]: local jShapley = -6.424712628989918e-06
# k = 2, review 33, coalition [3]: local jShapley = 3.251891629865011e-05
# k = 2, review 33, coalition [174]: local jShapley = 4.645192732251604e-05
# k = 2, review 33, coalition [269]: local jShapley = 0.0003556655990079815
# k = 2, review 33, coalition [1003]: local jShapley = 3.8891389944436147e-08
# k = 2, review 33, coalition [455]: local jShapley = 2.2586515862774664e-05
# k = 2, review 33, coalition [848]: local jShapley = -0.0006376133359695069
# k = 2, review 34, coalition [209, 978]: local jShapley = 2.6759581475948566e-06
# k = 2, review 34, coalition [101, 434]: local jShapley = -4.9588874682506146e-05
# k = 2, review 34, coalition [3, 174]: local jShapley = -1.7366000345194103e-06
# k = 2, review 34, coalition [269, 1003]: local jShapley = -2.10216793271228e-05
# k = 2, review 34, coalition [455, 848]: local jShapley = 7.714052957473535e-07
# k = 2, review 34, coalition [209]: local jShapley = 0.00010612134085324265
# k = 2, review 34, coalition [978]: local jShapley = -8.948362982145361e-05
# k = 2, review 34, coalition [101]: local jShapley = -0.0007609846713817559
# k = 2, review 34, coalition [434]: local jShapley = -2.1996492539012364e-05
# k = 2, review 34, coalition [3]: local jShapley = -1.9328082632890492e-05
# k = 2, review 34, coalition [174]: local jShapley = -1.1416456643612635e-05
# k = 2, review 34, coalition [269]: local jShapley = -0.00036444119381334955
# k = 2, review 34, coalition [1003]: local jShapley = -4.14322087993368e-05
# k = 2, review 34, coalition [455]: local jShapley = 0.0005611154218471104
# k = 2, review 34, coalition [848]: local jShapley = -0.0010791077976017953
# k = 2, review 35, coalition [209, 978]: local jShapley = -6.5092484433726224e-06
# k = 2, review 35, coalition [101, 434]: local jShapley = -2.995076760686302e-05
# k = 2, review 35, coalition [3, 174]: local jShapley = 1.8290372153343907e-09
# k = 2, review 35, coalition [269, 1003]: local jShapley = -8.477203985271684e-06
# k = 2, review 35, coalition [455, 848]: local jShapley = 2.2440162588935168e-06
# k = 2, review 35, coalition [209]: local jShapley = 9.905833181560326e-05
# k = 2, review 35, coalition [978]: local jShapley = -0.0001323836474386495
# k = 2, review 35, coalition [101]: local jShapley = -3.692976282004573e-08
# k = 2, review 35, coalition [434]: local jShapley = -4.529512169200867e-05
# k = 2, review 35, coalition [3]: local jShapley = -4.4083475790154215e-05
# k = 2, review 35, coalition [174]: local jShapley = 6.6343935109600855e-06
# k = 2, review 35, coalition [269]: local jShapley = -0.00018153827049789632
# k = 2, review 35, coalition [1003]: local jShapley = -5.8650049731130336e-05
# k = 2, review 35, coalition [455]: local jShapley = 0.00068526680254978
# k = 2, review 35, coalition [848]: local jShapley = 0.0
# k = 2, review 36, coalition [209, 978]: local jShapley = -1.2056777318682324e-06
# k = 2, review 36, coalition [101, 434]: local jShapley = -1.4966362519875877e-05
# k = 2, review 36, coalition [3, 174]: local jShapley = 1.5833562164746356e-07
# k = 2, review 36, coalition [269, 1003]: local jShapley = -2.7348413456885248e-05
# k = 2, review 36, coalition [455, 848]: local jShapley = -7.725103882326184e-06
# k = 2, review 36, coalition [209]: local jShapley = 0.00024201796396319995
# k = 2, review 36, coalition [978]: local jShapley = 0.0
# k = 2, review 36, coalition [101]: local jShapley = -0.0002286315646019522
# k = 2, review 36, coalition [434]: local jShapley = -6.397463069588061e-07
# k = 2, review 36, coalition [3]: local jShapley = 9.865214706865068e-05
# k = 2, review 36, coalition [174]: local jShapley = -6.151406797680827e-07
# k = 2, review 36, coalition [269]: local jShapley = -0.0003519939874040056
# k = 2, review 36, coalition [1003]: local jShapley = -9.870054808574161e-06
# k = 2, review 36, coalition [455]: local jShapley = 0.0007523593542717433
# k = 2, review 36, coalition [848]: local jShapley = -0.00041385794995811006
# k = 2, review 37, coalition [209, 978]: local jShapley = 6.777349898420348e-07
# k = 2, review 37, coalition [101, 434]: local jShapley = 2.491101486325044e-06
# k = 2, review 37, coalition [3, 174]: local jShapley = -7.552153663316194e-10
# k = 2, review 37, coalition [269, 1003]: local jShapley = -5.428110445508514e-10
# k = 2, review 37, coalition [455, 848]: local jShapley = 6.368707583794349e-07
# k = 2, review 37, coalition [209]: local jShapley = 0.0
# k = 2, review 37, coalition [978]: local jShapley = -4.637627674602325e-06
# k = 2, review 37, coalition [101]: local jShapley = 0.00039439157261295
# k = 2, review 37, coalition [434]: local jShapley = -2.2714362778403414e-05
# k = 2, review 37, coalition [3]: local jShapley = -5.646074592810686e-07
# k = 2, review 37, coalition [174]: local jShapley = -1.8149315307403536e-07
# k = 2, review 37, coalition [269]: local jShapley = -5.970169509014321e-10
# k = 2, review 37, coalition [1003]: local jShapley = -1.1160805456423058e-06
# k = 2, review 37, coalition [455]: local jShapley = 1.511280180698301e-05
# k = 2, review 37, coalition [848]: local jShapley = -0.0005128635737057623
# k = 2, review 38, coalition [209, 978]: local jShapley = -1.7393789910627088e-06
# k = 2, review 38, coalition [101, 434]: local jShapley = 3.550692245768504e-07
# k = 2, review 38, coalition [3, 174]: local jShapley = -1.0620216089038397e-10
# k = 2, review 38, coalition [269, 1003]: local jShapley = -1.2797950399296215e-07
# k = 2, review 38, coalition [455, 848]: local jShapley = -7.732083724344702e-06
# k = 2, review 38, coalition [209]: local jShapley = 0.00023875368849601052
# k = 2, review 38, coalition [978]: local jShapley = -0.00019007791567545457
# k = 2, review 38, coalition [101]: local jShapley = 0.0005893095047093626
# k = 2, review 38, coalition [434]: local jShapley = 7.819071304260967e-05
# k = 2, review 38, coalition [3]: local jShapley = -6.140234051885386e-06
# k = 2, review 38, coalition [174]: local jShapley = -5.083769913197381e-06
# k = 2, review 38, coalition [269]: local jShapley = -0.00024675192458723704
# k = 2, review 38, coalition [1003]: local jShapley = -7.761083900701268e-05
# k = 2, review 38, coalition [455]: local jShapley = 0.0002543550633891705
# k = 2, review 38, coalition [848]: local jShapley = -0.00029796297253386386
# k = 2, review 39, coalition [209, 978]: local jShapley = 6.202725406562777e-06
# k = 2, review 39, coalition [101, 434]: local jShapley = -4.784567831377143e-05
# k = 2, review 39, coalition [3, 174]: local jShapley = -1.1578985597076585e-07
# k = 2, review 39, coalition [269, 1003]: local jShapley = -2.0948376235628237e-05
# k = 2, review 39, coalition [455, 848]: local jShapley = -2.8874219902397393e-05
# k = 2, review 39, coalition [209]: local jShapley = 0.00011261070188920162
# k = 2, review 39, coalition [978]: local jShapley = -5.908028573239066e-05
# k = 2, review 39, coalition [101]: local jShapley = -0.00037263887621024504
# k = 2, review 39, coalition [434]: local jShapley = -3.108513744699239e-05
# k = 2, review 39, coalition [3]: local jShapley = -6.93424527455033e-05
# k = 2, review 39, coalition [174]: local jShapley = -4.76619953938574e-06
# k = 2, review 39, coalition [269]: local jShapley = -0.0002769670804045623
# k = 2, review 39, coalition [1003]: local jShapley = -6.634308222824242e-06
# k = 2, review 39, coalition [455]: local jShapley = 0.0007245444624614494
# k = 2, review 39, coalition [848]: local jShapley = -0.0003365651504096561
# k = 2, review 40, coalition [209, 978]: local jShapley = 1.698656362481296e-06
# k = 2, review 40, coalition [101, 434]: local jShapley = -2.438696620045689e-06
# k = 2, review 40, coalition [3, 174]: local jShapley = 3.176146724908367e-06
# k = 2, review 40, coalition [269, 1003]: local jShapley = -4.946660649472106e-08
# k = 2, review 40, coalition [455, 848]: local jShapley = -9.935949666301603e-06
# k = 2, review 40, coalition [209]: local jShapley = 0.00022425525977557304
# k = 2, review 40, coalition [978]: local jShapley = -5.88684300029565e-05
# k = 2, review 40, coalition [101]: local jShapley = -0.0002548451290177248
# k = 2, review 40, coalition [434]: local jShapley = 0.0
# k = 2, review 40, coalition [3]: local jShapley = 6.129641265413678e-05
# k = 2, review 40, coalition [174]: local jShapley = -4.088713232316379e-07
# k = 2, review 40, coalition [269]: local jShapley = -0.0003452219814858628
# k = 2, review 40, coalition [1003]: local jShapley = -1.0107923419440461e-05
# k = 2, review 40, coalition [455]: local jShapley = 0.0005944204815378939
# k = 2, review 40, coalition [848]: local jShapley = -0.00042079375174113953
# k = 2, review 41, coalition [209, 978]: local jShapley = 3.764276591559165e-08
# k = 2, review 41, coalition [101, 434]: local jShapley = -1.1084555536931354e-06
# k = 2, review 41, coalition [3, 174]: local jShapley = -8.582314623952918e-08
# k = 2, review 41, coalition [269, 1003]: local jShapley = -2.0159530185014665e-07
# k = 2, review 41, coalition [455, 848]: local jShapley = 8.21296710885636e-09
# k = 2, review 41, coalition [209]: local jShapley = 6.808939945369704e-05
# k = 2, review 41, coalition [978]: local jShapley = -4.119263442575364e-05
# k = 2, review 41, coalition [101]: local jShapley = -0.00011792108237933401
# k = 2, review 41, coalition [434]: local jShapley = -1.605242119956602e-05
# k = 2, review 41, coalition [3]: local jShapley = 1.5269134959983343e-05
# k = 2, review 41, coalition [174]: local jShapley = -2.01934160591542e-05
# k = 2, review 41, coalition [269]: local jShapley = -0.00036774713253489834
# k = 2, review 41, coalition [1003]: local jShapley = -5.3311993240916866e-05
# k = 2, review 41, coalition [455]: local jShapley = 0.0010073462321712392
# k = 2, review 41, coalition [848]: local jShapley = -0.00011081572778224853
# k = 2, review 42, coalition [209, 978]: local jShapley = 3.125125891965655e-07
# k = 2, review 42, coalition [101, 434]: local jShapley = -9.209308581369546e-06
# k = 2, review 42, coalition [3, 174]: local jShapley = -1.0260308766020985e-08
# ...
# k = 2, review 86, coalition [101, 434]: local jShapley = -1.8585378155817195e-08
# k = 2, review 86, coalition [3, 174]: local jShapley = 3.043775566812531e-08
# k = 2, review 86, coalition [269, 1003]: local jShapley = -1.2127106749671956e-07
# k = 2, review 86, coalition [455, 848]: local jShapley = -4.751922467143449e-05
# k = 2, review 86, coalition [209]: local jShapley = 0.00011301232372088659
# k = 2, review 86, coalition [978]: local jShapley = -0.00017643641949990023
# k = 2, review 86, coalition [101]: local jShapley = -0.0004360019909721309
# k = 2, review 86, coalition [434]: local jShapley = -2.458980624152442e-05
# k = 2, review 86, coalition [3]: local jShapley = 1.0809418336749645e-06
# k = 2, review 86, coalition [174]: local jShapley = 5.90884733934316e-06
# k = 2, review 86, coalition [269]: local jShapley = -0.00015305544465174745
# k = 2, review 86, coalition [1003]: local jShapley = -2.9889952155355647e-05
# k = 2, review 86, coalition [455]: local jShapley = 0.0004424816718046717
# k = 2, review 86, coalition [848]: local jShapley = -0.00047642890851428554
# k = 2, review 87, coalition [209, 978]: local jShapley = -1.6938028698554388e-07
# k = 2, review 87, coalition [101, 434]: local jShapley = -2.8787098729746984e-05
# k = 2, review 87, coalition [3, 174]: local jShapley = -6.709203511849018e-06
# k = 2, review 87, coalition [269, 1003]: local jShapley = -1.8880384158290484e-10
# k = 2, review 87, coalition [455, 848]: local jShapley = -2.1124022809500833e-05
# k = 2, review 87, coalition [209]: local jShapley = 1.6113231640422125e-05
# k = 2, review 87, coalition [978]: local jShapley = -3.791002200935796e-05
# k = 2, review 87, coalition [101]: local jShapley = -0.0001579054824286669
# k = 2, review 87, coalition [434]: local jShapley = -4.557473884537015e-05
# k = 2, review 87, coalition [3]: local jShapley = -1.4728365534670409e-05
# k = 2, review 87, coalition [174]: local jShapley = 2.6012881432133827e-09
# k = 2, review 87, coalition [269]: local jShapley = -0.00017691475800977603
# k = 2, review 87, coalition [1003]: local jShapley = -3.4758028373005925e-05
# k = 2, review 87, coalition [455]: local jShapley = 0.00028329089716884985
# k = 2, review 87, coalition [848]: local jShapley = -0.00039613912651637436
# k = 2, review 88, coalition [209, 978]: local jShapley = -2.6838643084611408e-06
# k = 2, review 88, coalition [101, 434]: local jShapley = -3.19185579454007e-05
# k = 2, review 88, coalition [3, 174]: local jShapley = 7.411695405418611e-06
# k = 2, review 88, coalition [269, 1003]: local jShapley = -2.7465176832664175e-06
# k = 2, review 88, coalition [455, 848]: local jShapley = -3.244599327710264e-05
# k = 2, review 88, coalition [209]: local jShapley = 7.533449866136136e-05
# k = 2, review 88, coalition [978]: local jShapley = -5.8552437459657955e-06
# k = 2, review 88, coalition [101]: local jShapley = -0.0005357706450271031
# k = 2, review 88, coalition [434]: local jShapley = -2.031222243238358e-06
# k = 2, review 88, coalition [3]: local jShapley = 3.57179889859875e-05
# k = 2, review 88, coalition [174]: local jShapley = 2.2858670304249877e-05
# k = 2, review 88, coalition [269]: local jShapley = 0.0
# k = 2, review 88, coalition [1003]: local jShapley = -2.441125552913697e-05
# k = 2, review 88, coalition [455]: local jShapley = 0.00047454885949182904
# k = 2, review 88, coalition [848]: local jShapley = -0.00024090329067179907
# k = 2, review 89, coalition [209, 978]: local jShapley = -7.19578641232846e-08
# k = 2, review 89, coalition [101, 434]: local jShapley = -6.700565736096601e-06
# k = 2, review 89, coalition [3, 174]: local jShapley = -2.4760561801989064e-06
# k = 2, review 89, coalition [269, 1003]: local jShapley = -2.4887019075009263e-05
# k = 2, review 89, coalition [455, 848]: local jShapley = -4.670140313125799e-05
# k = 2, review 89, coalition [209]: local jShapley = 0.0001537929738064503
# k = 2, review 89, coalition [978]: local jShapley = -0.00013190125774232116
# k = 2, review 89, coalition [101]: local jShapley = -0.00044465903526867717
# k = 2, review 89, coalition [434]: local jShapley = -7.108083817432451e-06
# k = 2, review 89, coalition [3]: local jShapley = -7.682584700471314e-06
# k = 2, review 89, coalition [174]: local jShapley = 3.469150362704834e-05
# k = 2, review 89, coalition [269]: local jShapley = -0.00033417912952131066
# k = 2, review 89, coalition [1003]: local jShapley = -1.8232897680529738e-06
# k = 2, review 89, coalition [455]: local jShapley = 0.0006278862667206737
# k = 2, review 89, coalition [848]: local jShapley = -0.0004916521158131174
# k = 2, review 90, coalition [209, 978]: local jShapley = 3.5043114020596537e-06
# k = 2, review 90, coalition [101, 434]: local jShapley = -7.969362952254017e-06
# k = 2, review 90, coalition [3, 174]: local jShapley = -3.7261065618330865e-08
# k = 2, review 90, coalition [269, 1003]: local jShapley = -1.7116248263500216e-07
# k = 2, review 90, coalition [455, 848]: local jShapley = 1.7188229728103698e-07
# k = 2, review 90, coalition [209]: local jShapley = 0.000340441666759995
# k = 2, review 90, coalition [978]: local jShapley = -8.818545910578638e-05
# k = 2, review 90, coalition [101]: local jShapley = -0.0001717347830793477
# k = 2, review 90, coalition [434]: local jShapley = -1.0208989860414489e-05
# k = 2, review 90, coalition [3]: local jShapley = -3.3186892978572967e-05
# k = 2, review 90, coalition [174]: local jShapley = 1.4879027026637175e-05
# k = 2, review 90, coalition [269]: local jShapley = -0.00015054984979694997
# k = 2, review 90, coalition [1003]: local jShapley = -1.4104099024367118e-06
# k = 2, review 90, coalition [455]: local jShapley = 0.0003501899301105853
# k = 2, review 90, coalition [848]: local jShapley = -0.0004974857816607149
# k = 2, review 91, coalition [209, 978]: local jShapley = -5.277716385447632e-07
# k = 2, review 91, coalition [101, 434]: local jShapley = -6.467617751814353e-07
# k = 2, review 91, coalition [3, 174]: local jShapley = 4.004995589457319e-06
# k = 2, review 91, coalition [269, 1003]: local jShapley = -5.56245617903485e-07
# k = 2, review 91, coalition [455, 848]: local jShapley = -1.7864135680730398e-05
# k = 2, review 91, coalition [209]: local jShapley = 8.583440635313653e-06
# k = 2, review 91, coalition [978]: local jShapley = -1.1575433728824102e-05
# k = 2, review 91, coalition [101]: local jShapley = -3.3819603014324715e-05
# k = 2, review 91, coalition [434]: local jShapley = -7.904632362138724e-06
# k = 2, review 91, coalition [3]: local jShapley = 6.881473240497436e-07
# k = 2, review 91, coalition [174]: local jShapley = 3.4290947897061396e-06
# k = 2, review 91, coalition [269]: local jShapley = -1.040515257285353e-08
# k = 2, review 91, coalition [1003]: local jShapley = -5.867823746002647e-06
# k = 2, review 91, coalition [455]: local jShapley = 5.9212439698879494e-05
# k = 2, review 91, coalition [848]: local jShapley = -3.411525433722469e-10
# k = 2, review 92, coalition [209, 978]: local jShapley = 6.58835135287581e-06
# k = 2, review 92, coalition [101, 434]: local jShapley = -5.248097782799313e-06
# k = 2, review 92, coalition [3, 174]: local jShapley = -1.0593783551216792e-06
# k = 2, review 92, coalition [269, 1003]: local jShapley = -2.6796575228658716e-06
# k = 2, review 92, coalition [455, 848]: local jShapley = 1.3370704553098105e-05
# k = 2, review 92, coalition [209]: local jShapley = 0.00010232043243532868
# k = 2, review 92, coalition [978]: local jShapley = -0.00011640802820541018
# k = 2, review 92, coalition [101]: local jShapley = -0.0004611306476559118
# k = 2, review 92, coalition [434]: local jShapley = -9.023936799315899e-05
# k = 2, review 92, coalition [3]: local jShapley = -0.00011346968134934501
# k = 2, review 92, coalition [174]: local jShapley = 2.80150204210497e-06
# k = 2, review 92, coalition [269]: local jShapley = -0.0004939091383960002
# k = 2, review 92, coalition [1003]: local jShapley = -5.481566571989797e-05
# k = 2, review 92, coalition [455]: local jShapley = 0.000686835720452681
# k = 2, review 92, coalition [848]: local jShapley = -0.00030042784230379624
# k = 2, review 93, coalition [209, 978]: local jShapley = -1.8998976571284747e-06
# k = 2, review 93, coalition [101, 434]: local jShapley = -5.831318749568955e-06
# k = 2, review 93, coalition [3, 174]: local jShapley = 3.017675400499766e-07
# k = 2, review 93, coalition [269, 1003]: local jShapley = -5.337508202028917e-06
# k = 2, review 93, coalition [455, 848]: local jShapley = 1.7818362549386644e-09
# k = 2, review 93, coalition [209]: local jShapley = 0.0002442180140713397
# k = 2, review 93, coalition [978]: local jShapley = -6.990326488273936e-05
# k = 2, review 93, coalition [101]: local jShapley = -0.00017581496749807977
# k = 2, review 93, coalition [434]: local jShapley = -5.1823544694183754e-05
# k = 2, review 93, coalition [3]: local jShapley = 4.8238159395545206e-05
# k = 2, review 93, coalition [174]: local jShapley = 4.000307815108253e-05
# k = 2, review 93, coalition [269]: local jShapley = -0.00018627781749483113
# k = 2, review 93, coalition [1003]: local jShapley = -1.1339654677285959e-05
# k = 2, review 93, coalition [455]: local jShapley = 0.0002845263811046724
# k = 2, review 93, coalition [848]: local jShapley = -0.000404610072100511
# k = 2, review 94, coalition [209, 978]: local jShapley = 1.191544584301742e-05
# k = 2, review 94, coalition [101, 434]: local jShapley = -3.018359814425504e-06
# k = 2, review 94, coalition [3, 174]: local jShapley = -1.671940618897315e-06
# k = 2, review 94, coalition [269, 1003]: local jShapley = -2.1147210281295234e-07
# k = 2, review 94, coalition [455, 848]: local jShapley = 8.052955853114848e-06
# k = 2, review 94, coalition [209]: local jShapley = 8.057157399873666e-05
# k = 2, review 94, coalition [978]: local jShapley = -9.558121980541748e-05
# k = 2, review 94, coalition [101]: local jShapley = -0.0001014505584565396
# k = 2, review 94, coalition [434]: local jShapley = -1.4662864246342939e-05
# k = 2, review 94, coalition [3]: local jShapley = -9.778242130339106e-06
# k = 2, review 94, coalition [174]: local jShapley = 2.3162338711919097e-05
# k = 2, review 94, coalition [269]: local jShapley = -0.00022145853386907526
# k = 2, review 94, coalition [1003]: local jShapley = -4.007928310045831e-05
# k = 2, review 94, coalition [455]: local jShapley = 0.0005004838728559382
# k = 2, review 94, coalition [848]: local jShapley = -0.0007819459365279052
# k = 2, review 95, coalition [209, 978]: local jShapley = 1.1390771767498627e-07
# k = 2, review 95, coalition [101, 434]: local jShapley = -3.485071110578346e-06
# k = 2, review 95, coalition [3, 174]: local jShapley = 2.8506017010590437e-06
# k = 2, review 95, coalition [269, 1003]: local jShapley = -1.8867462895382153e-06
# k = 2, review 95, coalition [455, 848]: local jShapley = 1.0863566540478612e-05
# k = 2, review 95, coalition [209]: local jShapley = 9.801193167694473e-05
# k = 2, review 95, coalition [978]: local jShapley = -0.00024154256789401073
# k = 2, review 95, coalition [101]: local jShapley = -0.0008637524400895815
# k = 2, review 95, coalition [434]: local jShapley = -3.0123428427226028e-05
# k = 2, review 95, coalition [3]: local jShapley = 2.713970828289236e-05
# k = 2, review 95, coalition [174]: local jShapley = 3.1157291209915624e-05
# k = 2, review 95, coalition [269]: local jShapley = -0.00045423275644926455
# k = 2, review 95, coalition [1003]: local jShapley = -2.10833124685407e-05
# k = 2, review 95, coalition [455]: local jShapley = 0.0012854395424096092
# k = 2, review 95, coalition [848]: local jShapley = -0.001855553075808502
# k = 2, review 96, coalition [209, 978]: local jShapley = 6.151937173176975e-07
# k = 2, review 96, coalition [101, 434]: local jShapley = -4.592163052322031e-06
# k = 2, review 96, coalition [3, 174]: local jShapley = 4.256517707166045e-06
# k = 2, review 96, coalition [269, 1003]: local jShapley = -2.0321913289016063e-05
# k = 2, review 96, coalition [455, 848]: local jShapley = -3.530602927012078e-05
# k = 2, review 96, coalition [209]: local jShapley = 0.0002627909981935436
# k = 2, review 96, coalition [978]: local jShapley = -0.0001508632410521053
# k = 2, review 96, coalition [101]: local jShapley = -0.0012509384871898983
# k = 2, review 96, coalition [434]: local jShapley = -4.750839146120405e-05
# k = 2, review 96, coalition [3]: local jShapley = -1.095781969311657e-06
# k = 2, review 96, coalition [174]: local jShapley = 1.3439704446149666e-06
# k = 2, review 96, coalition [269]: local jShapley = -1.530666173975429e-06
# k = 2, review 96, coalition [1003]: local jShapley = -3.827462879008705e-05
# k = 2, review 96, coalition [455]: local jShapley = 0.00024588740139826383
# k = 2, review 96, coalition [848]: local jShapley = -0.0006640529139452636
# k = 2, review 97, coalition [209, 978]: local jShapley = -1.599286540608193e-07
# k = 2, review 97, coalition [101, 434]: local jShapley = -3.643548335106997e-06
# k = 2, review 97, coalition [3, 174]: local jShapley = -6.363633480551808e-07
# k = 2, review 97, coalition [269, 1003]: local jShapley = -1.3848289770502113e-06
# k = 2, review 97, coalition [455, 848]: local jShapley = -3.0392503694846476e-05
# k = 2, review 97, coalition [209]: local jShapley = 0.00023545887987618926
# k = 2, review 97, coalition [978]: local jShapley = -6.344388262652923e-05
# k = 2, review 97, coalition [101]: local jShapley = -0.00018872294306131586
# k = 2, review 97, coalition [434]: local jShapley = -3.900955665664671e-05
# k = 2, review 97, coalition [3]: local jShapley = -3.177093934730646e-05
# k = 2, review 97, coalition [174]: local jShapley = -2.8383891608570943e-07
# k = 2, review 97, coalition [269]: local jShapley = -0.00016688755981091104
# k = 2, review 97, coalition [1003]: local jShapley = -4.204688039435775e-05
# k = 2, review 97, coalition [455]: local jShapley = 0.00040385612497965837
# k = 2, review 97, coalition [848]: local jShapley = -0.0008816791533624346
# k = 2, review 98, coalition [209, 978]: local jShapley = 4.068474981069522e-06
# k = 2, review 98, coalition [101, 434]: local jShapley = -7.674804768892482e-05
# k = 2, review 98, coalition [3, 174]: local jShapley = -4.035682113834591e-09
# k = 2, review 98, coalition [269, 1003]: local jShapley = -1.6508181891202274e-06
# k = 2, review 98, coalition [455, 848]: local jShapley = 3.4733310517039186e-05
# k = 2, review 98, coalition [209]: local jShapley = 7.594017235805087e-05
# k = 2, review 98, coalition [978]: local jShapley = -0.00016821916347582876
# k = 2, review 98, coalition [101]: local jShapley = -0.0004120149159866094
# k = 2, review 98, coalition [434]: local jShapley = -2.026791524581311e-05
# k = 2, review 98, coalition [3]: local jShapley = -6.073687983893837e-05
# k = 2, review 98, coalition [174]: local jShapley = -9.766344435388997e-07
# k = 2, review 98, coalition [269]: local jShapley = -4.264406792153087e-09
# k = 2, review 98, coalition [1003]: local jShapley = -1.9322624192196535e-05
# k = 2, review 98, coalition [455]: local jShapley = 0.0005906710018658933
# k = 2, review 98, coalition [848]: local jShapley = -0.0007211047492988307
# k = 2, review 99, coalition [209, 978]: local jShapley = -4.7289462196468193e-07
# k = 2, review 99, coalition [101, 434]: local jShapley = -3.9376935941878735e-07
# k = 2, review 99, coalition [3, 174]: local jShapley = 4.473895830148513e-06
# k = 2, review 99, coalition [269, 1003]: local jShapley = -2.87018419950322e-06
# k = 2, review 99, coalition [455, 848]: local jShapley = 1.5186673002522927e-06
# k = 2, review 99, coalition [209]: local jShapley = 0.0002710809623534213
# k = 2, review 99, coalition [978]: local jShapley = -5.0797144623380425e-05
# k = 2, review 99, coalition [101]: local jShapley = -0.000468328539880387
# k = 2, review 99, coalition [434]: local jShapley = -5.940190729265485e-06
# k = 2, review 99, coalition [3]: local jShapley = 3.3957385997779184e-05
# k = 2, review 99, coalition [174]: local jShapley = 6.780406799523407e-08
# k = 2, review 99, coalition [269]: local jShapley = -0.00020117240960625967
# k = 2, review 99, coalition [1003]: local jShapley = -1.9893116532850773e-05
# k = 2, review 99, coalition [455]: local jShapley = 0.0008273154721184369
# k = 2, review 99, coalition [848]: local jShapley = -0.0006637270706222751

# %% [markdown]
# #### Also obtain Joint Shapley values for the target vocab

# %%
target_vocab_DSA_scores = {}
for key, ss_reviews in target_vocab_DSA.items():
    scores = []
    for review in ss_to_vc(ss_reviews, DSA_vectorizer):
        try:
            score = calculate_phi_t(
                sample_review_oh,
                value_f,
                review,
                num_DSA_features,
                q_values,
                num_sampling_iterations
            )
        except:
            score = np.nan
        scores.append(score)
    target_vocab_DSA_scores[key] = scores

# %%
target_vocab_DSA_scores
# Out:
# {'t2dsa': [-2.6518502570727393248e-05,
#   2.5762638191190331814e-06,
#   -2.7324989980288869322e-06,
#   -4.8414025077896372298e-06,
#   -3.453807554460236161e-05]}

# %% [markdown]
# #### Obtain local Joint Shapleys for the training set

# %%
local_js = []
for review_vc in ss_to_vc(test_reviews_ss, DSA_vectorizer): 
    local_js.append(
        calculate_phi_t(
            sample_review_oh,
            value_f,
            review_vc,
            num_DSA_features,
            q_values,
            num_sampling_iterations
        )
    )

# %%
local_js
# Out:
# [-1.4401536259954464885e-06,
#  -8.094926488781691064e-06,
#  -3.140564245186040394e-10,
#  -1.0724492182556556451e-05,
#  1.0591149488923686805e-08,
#  0.0,
#  -2.1118762019821207003e-11,
#  -3.3941721975163192355e-06,
#  0.0,
#  -3.619627351185566415e-08,
#  -7.7401866010067979285e-11,
#  8.2197877621504616695e-12,
#  1.7810941782873765561e-07,
#  1.7032736599413580522e-09,
#  1.1793156054803456867e-07,
#  -5.9086500725978570868e-06,
#  -4.3134532425085626059e-07,
#  1.8195069190250120905e-07,
#  -1.029710269261762603e-05,
#  4.577791368546115495e-06,
#  -2.7046859609197213494e-08,
#  -5.1498207815564422977e-09,
#  2.7057587286976191077e-10,
#  1.8445871975592772319e-08,
#  -0.00041423842033210597733,
#  1.0006447628727950007e-06,
#  -8.186545097467101388e-06,
#  -4.951777638167366587e-08,
#  2.2552033302381207335e-08,
#  2.99021404392331499e-07,
#  -3.0312928600462652466e-07,
#  -2.1536013737310368215e-08,
#  -1.4180669385854150106e-10,
#  9.875767342274705461e-09,
#  4.5773483539614130483e-06,
#  -1.7848095328611474337e-05,
#  -3.927822373716520294e-07,
#  -6.430863043733351753e-09,
#  1.189478782970930653e-11,
#  -4.9497159894322527972e-06,
#  -1.7449052587145072302e-06,
#  -2.704887307067032929e-07,
#  -1.6024766673396825939e-08,
#  -6.5361675178739592386e-06,
#  3.676922074698294703e-08,
#  -2.2057871896332244188e-07,
#  -9.795558985603874819e-11,
#  -1.0643468707584911787e-09,
#  -1.5976278395888805118e-08,
#  -2.6493859509152377952e-10,
#  3.3832795879697879877e-07,
#  8.9930592122422480463e-07,
#  -7.8004248176007171765e-07,
#  3.7806092522390034844e-06,
#  -1.2890616012058710794e-07,
#  1.7029837022913643318e-07,
#  -7.0863277370459938073e-10,
#  -3.032719173309810106e-07,
#  -6.224938964214537033e-10,
#  -2.7986933215759429293e-06,
#  1.1220006755956397721e-06,
#  4.6055127576923983773e-08,
#  -6.7223869225615031534e-08,
#  8.815740798830144596e-07,
#  4.20278444034477606e-08,
#  -2.4055998493473899857e-09,
#  -1.533518171476387231e-08,
#  -1.2575548340794955102e-06,
#  -1.085242293999193499e-09,
#  8.7912715809634935804e-09,
#  2.295086732412591435e-06,
#  4.2359173991800540076e-11,
#  5.7733458012919677873e-08,
#  5.9780274633821537906e-12,
#  1.1543517674068572756e-07,
#  0.0,
#  -5.671994952846599477e-12,
#  4.3716566229757365436e-05,
#  -3.0728201893415709674e-09,
#  2.702341790967034281e-05,
#  1.0000152284226985692e-06,
#  -1.1016180108501736603e-06,
#  5.9536762941915453696e-11,
#  8.461942538927272553e-07,
#  1.0885628009770479105e-07,
#  2.0190235538354278034e-07,
#  -6.1515485089242290854e-09,
#  6.9796835389398187616e-09,
#  -1.2302265441505568111e-09,
#  -1.6395327511043787252e-07,
#  -8.633823816335946864e-06,
#  1.4754717625528154128e-05,
#  5.9172570091948857116e-08,
#  -6.938626233997095733e-11,
#  8.991620065779740315e-09,
#  -3.3521115377272625446e-08,
#  -7.8551348395798823824e-10,
#  -1.5934080771516509909e-06,
#  1.8988396465132051813e-07,
#  1.4135292678623244953e-07]
